# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import glob

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# CSV 파일들을 저장할 빈 DataFrame을 생성합니다.
stock = pd.DataFrame()

# data 폴더에 있는 모든 CSV 파일을 가져옵니다.
csv_files = glob.glob('data/*.csv')

# 모든 CSV 파일을 순회하며 데이터를 DataFrame에 추가합니다.
for csv_file in csv_files:
    tmp = pd.read_csv(csv_file)
    stock = pd.concat([stock, tmp], ignore_index=True)

# all_data DataFrame에 모든 CSV 파일의 내용이 포함됩니다.
# Date,Open,High,Low,Close,Volume,Change,ma5,ma10,ma20,Kospi,S&P500,rsi,%K,%D,bb_upper,bb_sma,bb_lower,volume_ma5,momentum,high_low_diff

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from itertools import combinations
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import Huber

scaler = MinMaxScaler()
use_cols = ['Open', 'High', 'Low','Close','Volume']

colList = ['ma10', 'ma20', 'S&P500', 'Kospi', 'rsi', '%K', '%D', 'bb_upper', 'bb_lower', 'volume_ma5', 'momentum', 'high_low_diff']
result_pridict = []
com_colList = []

for r in range(2,3):
    for combination in combinations(colList, r):
        com_colList.append(list(combination))

for plus_cols in com_colList:
    use_cols.extend(plus_cols)

    scaled = scaler.fit_transform(stock[use_cols])
    df = pd.DataFrame(scaled, columns=use_cols)

    ln_use_cols = len(use_cols)
    WINDOW_SIZE = 20
    BATCH_SIZE = 100

    X, y = [], []

    for i in range(WINDOW_SIZE, len(scaled)):
        X.append(scaled[i - WINDOW_SIZE:i])
        y.append([scaled[i]])

    X, y = np.array(X), np.array(y)

    split_ratio = 0.8
    split_index = int(split_ratio * len(X))

    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]

    model = Sequential([
        GRU(64, activation='tanh', input_shape=(WINDOW_SIZE, ln_use_cols)),
        Dense(32, activation='relu'),
        Dense(ln_use_cols)
    ])

    loss = Huber()
    optimizer = Adam(learning_rate=0.001)
    model.compile(loss=loss, optimizer=optimizer)

    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

    tmp = '_'.join(use_cols[5:])
    checkpoint = ModelCheckpoint(
        filepath=f'./checkpoint/GRU//GRU_{tmp}.h5',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )

    history = model.fit(
        X_train,
        y_train,
        validation_split=0.2,
        epochs=50,
        callbacks=[early_stopping, checkpoint],
        batch_size=32
    )

    input_scaled = stock[use_cols]
    total_data = [[input_scaled[len(input_scaled)-WINDOW_SIZE-1:len(input_scaled)-1]]]
    conform_total_data = [[input_scaled[len(input_scaled)-1:len(input_scaled)]]][:4]

    data = np.array(total_data)
    data = data.tolist()
    data = data[0]

    conform_data = conform_total_data[0][0]
    conform_data = conform_data.values[0]

    data_2d = np.array(data).reshape(-1, len(data[0][0]))

    scaler = MinMaxScaler()
    scaler.fit(data_2d)

    scaled_data_2d = scaler.transform(data_2d)

    scaled_data_3d = scaled_data_2d.reshape(len(data), len(data[0]), len(data[0][0]))

    predicted_value = model.predict(scaled_data_3d)
    
    predicted_value_original = scaler.inverse_transform(predicted_value)
    predicted_value_original = np.round(predicted_value_original, ln_use_cols)[0][:4]
    conform_total_data = conform_total_data[0][0].values[0]
    predicted_value_original = list(predicted_value_original)
    predicted_value_original.extend(conform_total_data[:4])
    
    use_cols_check = '/'.join(use_cols)
    predicted_value_original.append(use_cols_check)
    result_use_cols = use_cols[:4]
    result_use_cols.extend(['_Open', '_High', '_Low', '_Close', 'Use_Cols_Check'])

    result_dict = dict(zip(result_use_cols, predicted_value_original))
    result_pridict.append(result_dict)

    use_cols = use_cols[:5]  # 초기 use_cols로 재설정
# Out:
# Epoch 1/50
# 988/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 1: val_loss improved from inf to 0.00163, saving model to ./checkpoint/GRU\GRU_ma10_ma20.h5
# 992/992 [==============================] - 17s 15ms/step - loss: 0.0071 - val_loss: 0.0016
# Epoch 2/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 2: val_loss improved from 0.00163 to 0.00153, saving model to ./checkpoint/GRU\GRU_ma10_ma20.h5
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 3/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 3: val_loss improved from 0.00153 to 0.00151, saving model to ./checkpoint/GRU\GRU_ma10_ma20.h5
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 4/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 4: val_loss improved from 0.00151 to 0.00144, saving model to ./checkpoint/GRU\GRU_ma10_ma20.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 5/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 5: val_loss did not improve from 0.00144
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 6/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 6: val_loss did not improve from 0.00144
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 7: val_loss improved from 0.00144 to 0.00140, saving model to ./checkpoint/GRU\GRU_ma10_ma20.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 8: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 9/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 9: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0016
# Epoch 10/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 10: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 11/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 11: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0017
# Epoch 12/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 12: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 13/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 13: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 14/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 14: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 15/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 15: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 16/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 16: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 17/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 17: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 18/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 18: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 19/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 19: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 20/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 20: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 21/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 21: val_loss did not improve from 0.00140
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 22/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 22: val_loss did not improve from 0.00140
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 23/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 23: val_loss did not improve from 0.00140
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 24/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 24: val_loss did not improve from 0.00140
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 25/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 25: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 26/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 26: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 27/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 27: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 1: val_loss improved from inf to 0.00433, saving model to ./checkpoint/GRU\GRU_ma10_S&P500.h5
# 992/992 [==============================] - 28s 20ms/step - loss: 0.0087 - val_loss: 0.0043
# Epoch 2/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 2: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0087 - val_loss: 0.0046
# Epoch 3/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 3: val_loss did not improve from 0.00433
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 4/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 4: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 5/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 5: val_loss did not improve from 0.00433
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 6/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 6: val_loss did not improve from 0.00433
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 7: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0044
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 8: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 9: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 10/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 10: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 11/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 11: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0044
# Epoch 12/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 12: val_loss did not improve from 0.00433
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 13/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 13: val_loss did not improve from 0.00433
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 14/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 14: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 15/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 15: val_loss did not improve from 0.00433
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 16/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 16: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 17/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 17: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 18/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 18: val_loss did not improve from 0.00433
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 19/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 19: val_loss did not improve from 0.00433
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 20/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 20: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 21/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 21: val_loss did not improve from 0.00433
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# 1/1 [==============================] - 0s 455ms/step
# Epoch 1/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 1: val_loss improved from inf to 0.00438, saving model to ./checkpoint/GRU\GRU_ma10_Kospi.h5
# 992/992 [==============================] - 22s 19ms/step - loss: 0.0097 - val_loss: 0.0044
# Epoch 2/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 2: val_loss did not improve from 0.00438
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0046
# Epoch 3/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 3: val_loss did not improve from 0.00438
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 4/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 4: val_loss improved from 0.00438 to 0.00431, saving model to ./checkpoint/GRU\GRU_ma10_Kospi.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 5/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 5: val_loss did not improve from 0.00431
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 6/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 6: val_loss did not improve from 0.00431
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0046
# Epoch 7/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 7: val_loss did not improve from 0.00431
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 8: val_loss improved from 0.00431 to 0.00429, saving model to ./checkpoint/GRU\GRU_ma10_Kospi.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 9/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 9: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 10/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 10: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 11/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 11: val_loss did not improve from 0.00429
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 12/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 12: val_loss did not improve from 0.00429
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 13/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 13: val_loss did not improve from 0.00429
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 14/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 14: val_loss did not improve from 0.00429
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0048
# Epoch 15/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 15: val_loss did not improve from 0.00429
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 16/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 16: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 17/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 17: val_loss did not improve from 0.00429
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 18/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 18: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 19/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 19: val_loss did not improve from 0.00429
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 20/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 20: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 21/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 21: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 22/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 22: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 23/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 23: val_loss did not improve from 0.00429
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 24/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 24: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 25/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 25: val_loss did not improve from 0.00429
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 26/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 26: val_loss did not improve from 0.00429
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 27/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 27: val_loss did not improve from 0.00429
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 28/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 28: val_loss did not improve from 0.00429
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 1: val_loss improved from inf to 0.00299, saving model to ./checkpoint/GRU\GRU_ma10_rsi.h5
# 992/992 [==============================] - 26s 20ms/step - loss: 0.0080 - val_loss: 0.0030
# Epoch 2/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 2: val_loss did not improve from 0.00299
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 3: val_loss did not improve from 0.00299
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 4/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 4: val_loss did not improve from 0.00299
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 5/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 5: val_loss did not improve from 0.00299
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 6/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 6: val_loss did not improve from 0.00299
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 7/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 7: val_loss improved from 0.00299 to 0.00299, saving model to ./checkpoint/GRU\GRU_ma10_rsi.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 8/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 8: val_loss improved from 0.00299 to 0.00298, saving model to ./checkpoint/GRU\GRU_ma10_rsi.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 9/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 9: val_loss improved from 0.00298 to 0.00294, saving model to ./checkpoint/GRU\GRU_ma10_rsi.h5
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 10/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 10: val_loss improved from 0.00294 to 0.00294, saving model to ./checkpoint/GRU\GRU_ma10_rsi.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 11/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 11: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 12/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 12: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 13/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 13: val_loss did not improve from 0.00294
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 14/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 14: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 15/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 15: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 16/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 16: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 17/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 17: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 18/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 18: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 19/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 19: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 20/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 20: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 21/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 21: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 22/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 22: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 23/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 23: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 24/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 24: val_loss did not improve from 0.00294
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 25/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 25: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 26/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 26: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 27/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 27: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 28/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 28: val_loss did not improve from 0.00294
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 29/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 29: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 30/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 30: val_loss did not improve from 0.00294
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0031
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 1: val_loss improved from inf to 0.00599, saving model to ./checkpoint/GRU\GRU_ma10_%K.h5
# 992/992 [==============================] - 27s 19ms/step - loss: 0.0110 - val_loss: 0.0060
# Epoch 2/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 2: val_loss improved from 0.00599 to 0.00592, saving model to ./checkpoint/GRU\GRU_ma10_%K.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 3/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 3: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0062
# Epoch 4/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 4: val_loss did not improve from 0.00592
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 5/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 5: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 6/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 6: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 7: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 8/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 8: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 9: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 10/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 10: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 11/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 11: val_loss improved from 0.00592 to 0.00592, saving model to ./checkpoint/GRU\GRU_ma10_%K.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 12/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 12: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 13/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 13: val_loss did not improve from 0.00592
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 14/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 14: val_loss did not improve from 0.00592
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 15/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 15: val_loss improved from 0.00592 to 0.00590, saving model to ./checkpoint/GRU\GRU_ma10_%K.h5
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 16/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 16: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 17/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 17: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 18/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 18: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 19/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 19: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 20/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 20: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 21/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 21: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 22/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 22: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 23/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 23: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 24/50
# 988/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 24: val_loss did not improve from 0.00590
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 25/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 25: val_loss did not improve from 0.00590
# 992/992 [==============================] - 14s 15ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 26/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 26: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 27/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 27: val_loss did not improve from 0.00590
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 28/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 28: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 29/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 29: val_loss did not improve from 0.00590
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 30/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 30: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 31/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 31: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 32/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 32: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 33/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 33: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 34/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 34: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 35/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 35: val_loss did not improve from 0.00590
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 1: val_loss improved from inf to 0.00613, saving model to ./checkpoint/GRU\GRU_ma10_%D.h5
# 992/992 [==============================] - 23s 18ms/step - loss: 0.0114 - val_loss: 0.0061
# Epoch 2/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 2: val_loss did not improve from 0.00613
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 3/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 3: val_loss improved from 0.00613 to 0.00608, saving model to ./checkpoint/GRU\GRU_ma10_%D.h5
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 4/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 4: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 5/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 5: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 6/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 6: val_loss did not improve from 0.00608
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 7/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 7: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 8/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 8: val_loss did not improve from 0.00608
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 9/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 9: val_loss did not improve from 0.00608
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 10/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 10: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 11/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 11: val_loss did not improve from 0.00608
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 12/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 12: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 13/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 13: val_loss did not improve from 0.00608
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 14/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 14: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 15/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 15: val_loss did not improve from 0.00608
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 16/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 16: val_loss did not improve from 0.00608
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0111 - val_loss: 0.0063
# Epoch 17/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 17: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 18/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 18: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 19/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 19: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 20/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 20: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 21/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 21: val_loss did not improve from 0.00608
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 22/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 22: val_loss did not improve from 0.00608
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 23/50
# 988/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 23: val_loss did not improve from 0.00608
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0111 - val_loss: 0.0062
# 1/1 [==============================] - 1s 714ms/step
# Epoch 1/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 1: val_loss improved from inf to 0.00146, saving model to ./checkpoint/GRU\GRU_ma10_bb_upper.h5
# 992/992 [==============================] - 25s 21ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 2/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 2: val_loss improved from 0.00146 to 0.00142, saving model to ./checkpoint/GRU\GRU_ma10_bb_upper.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 3/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 3: val_loss did not improve from 0.00142
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 4/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 4: val_loss improved from 0.00142 to 0.00142, saving model to ./checkpoint/GRU\GRU_ma10_bb_upper.h5
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 5/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 5: val_loss improved from 0.00142 to 0.00140, saving model to ./checkpoint/GRU\GRU_ma10_bb_upper.h5
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 6/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 6: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 7: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 8: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 9/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 9: val_loss did not improve from 0.00140
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 10/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 10: val_loss did not improve from 0.00140
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 11/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 11: val_loss did not improve from 0.00140
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 12/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 12: val_loss improved from 0.00140 to 0.00140, saving model to ./checkpoint/GRU\GRU_ma10_bb_upper.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 13/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 13: val_loss improved from 0.00140 to 0.00138, saving model to ./checkpoint/GRU\GRU_ma10_bb_upper.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 14/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 14: val_loss improved from 0.00138 to 0.00136, saving model to ./checkpoint/GRU\GRU_ma10_bb_upper.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 15/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 15: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 16/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 16: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 17/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 17: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 18/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 18: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 19/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 19: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 20/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 20: val_loss did not improve from 0.00136
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 21/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 21: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 22/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 22: val_loss did not improve from 0.00136
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 23/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 23: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 24/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 24: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 25/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 25: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 26/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 26: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 27/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 27: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 28/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 28: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 29/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 29: val_loss did not improve from 0.00136
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 30/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 30: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 31/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 31: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 32/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 32: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 33/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 33: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 34/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 34: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0070 - val_loss: 0.0015
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 1: val_loss improved from inf to 0.00136, saving model to ./checkpoint/GRU\GRU_ma10_bb_lower.h5
# 992/992 [==============================] - 32s 21ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 2/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 2: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 3: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 4/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 4: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 5/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 5: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 6/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 6: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 7/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 7: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 8/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 8: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 9/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 9: val_loss did not improve from 0.00136
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 10/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 10: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 11/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 11: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 12/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 12: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 13/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 13: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 14/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 14: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 15/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 15: val_loss did not improve from 0.00136
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 16/50
# ...
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 19: val_loss did not improve from 0.00138
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 20/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 20: val_loss did not improve from 0.00138
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 21/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 21: val_loss did not improve from 0.00138
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 22/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 22: val_loss did not improve from 0.00138
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 23/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 23: val_loss did not improve from 0.00138
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 1: val_loss improved from inf to 0.00151, saving model to ./checkpoint/GRU\GRU_ma20_bb_lower.h5
# 992/992 [==============================] - 25s 18ms/step - loss: 0.0073 - val_loss: 0.0015
# Epoch 2/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 2: val_loss improved from 0.00151 to 0.00147, saving model to ./checkpoint/GRU\GRU_ma20_bb_lower.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 3/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 3: val_loss improved from 0.00147 to 0.00145, saving model to ./checkpoint/GRU\GRU_ma20_bb_lower.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 4/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 4: val_loss did not improve from 0.00145
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 5/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 5: val_loss did not improve from 0.00145
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 6/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 6: val_loss did not improve from 0.00145
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 7/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 7: val_loss improved from 0.00145 to 0.00145, saving model to ./checkpoint/GRU\GRU_ma20_bb_lower.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 8: val_loss did not improve from 0.00145
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 9: val_loss did not improve from 0.00145
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 10/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 10: val_loss improved from 0.00145 to 0.00144, saving model to ./checkpoint/GRU\GRU_ma20_bb_lower.h5
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 11/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 11: val_loss did not improve from 0.00144
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 12/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 12: val_loss did not improve from 0.00144
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0016
# Epoch 13/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 13: val_loss improved from 0.00144 to 0.00144, saving model to ./checkpoint/GRU\GRU_ma20_bb_lower.h5
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 14/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 14: val_loss did not improve from 0.00144
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 15/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 15: val_loss improved from 0.00144 to 0.00143, saving model to ./checkpoint/GRU\GRU_ma20_bb_lower.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 16/50
# 988/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 16: val_loss did not improve from 0.00143
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 17/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 17: val_loss did not improve from 0.00143
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 18/50
# 988/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 18: val_loss did not improve from 0.00143
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 19/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 19: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 20/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 20: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 21/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 21: val_loss did not improve from 0.00143
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 22/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 22: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0016
# Epoch 23/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 23: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 24/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 24: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 25/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 25: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0016
# Epoch 26/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 26: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 27/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 27: val_loss did not improve from 0.00143
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 28/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 28: val_loss did not improve from 0.00143
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 29/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 29: val_loss did not improve from 0.00143
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 30/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 30: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 31/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 31: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 32/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 32: val_loss did not improve from 0.00143
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 33/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 33: val_loss did not improve from 0.00143
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 34/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 34: val_loss did not improve from 0.00143
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 35/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 35: val_loss did not improve from 0.00143
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0072 - val_loss: 0.0015
# 1/1 [==============================] - 1s 542ms/step
# Epoch 1/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 1: val_loss improved from inf to 0.00127, saving model to ./checkpoint/GRU\GRU_ma20_volume_ma5.h5
# 992/992 [==============================] - 28s 18ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 2/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 2: val_loss improved from 0.00127 to 0.00115, saving model to ./checkpoint/GRU\GRU_ma20_volume_ma5.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 3/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 3: val_loss did not improve from 0.00115
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 4/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 4: val_loss did not improve from 0.00115
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 5/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 5: val_loss did not improve from 0.00115
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 6/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 6: val_loss did not improve from 0.00115
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 7: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 8/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 8: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 9/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 9: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 10/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 10: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 11/50
# 988/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 11: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 12/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 12: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 13/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 13: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 14/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 14: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 15ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 15/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 15: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 16/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 16: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 17/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 17: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 18/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 18: val_loss did not improve from 0.00115
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 19/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 19: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 15ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 20/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 20: val_loss did not improve from 0.00115
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 21/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 21: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 22/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 22: val_loss did not improve from 0.00115
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0060 - val_loss: 0.0012
# 1/1 [==============================] - 1s 748ms/step
# Epoch 1/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 1: val_loss improved from inf to 0.00120, saving model to ./checkpoint/GRU\GRU_ma20_momentum.h5
# 992/992 [==============================] - 20s 15ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 2/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 2: val_loss did not improve from 0.00120
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 3: val_loss did not improve from 0.00120
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 4/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 4: val_loss did not improve from 0.00120
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 5/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 5: val_loss did not improve from 0.00120
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 6/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 6: val_loss improved from 0.00120 to 0.00117, saving model to ./checkpoint/GRU\GRU_ma20_momentum.h5
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 7/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 7: val_loss did not improve from 0.00117
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 8: val_loss did not improve from 0.00117
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 9/50
# 912/992 [==========================>...] - ETA: 1s - loss: 0.0059

# %%
print(result_pridict)
import pandas as pd


# 데이터를 DataFrame으로 변환
df = pd.DataFrame(result_pridict)

# DataFrame을 엑셀 파일로 저장
df.to_excel('GRU_result_pridict2.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\SSAFY\Desktop\S09P31C106\AI\TH\learning\GRULearing.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/learning/GRULearing.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> print(result_pridict)
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/learning/GRULearing.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/learning/GRULearing.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> # 데이터를 DataFrame으로 변환
#
# NameError: name 'result_pridict' is not defined
