# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import glob

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# CSV 파일들을 저장할 빈 DataFrame을 생성합니다.
stock = pd.DataFrame()

# data 폴더에 있는 모든 CSV 파일을 가져옵니다.
csv_files = glob.glob('data/*.csv')

# 모든 CSV 파일을 순회하며 데이터를 DataFrame에 추가합니다.
for csv_file in csv_files:
    tmp = pd.read_csv(csv_file)
    stock = pd.concat([stock, tmp], ignore_index=True)

# all_data DataFrame에 모든 CSV 파일의 내용이 포함됩니다.
# Date,Open,High,Low,Close,Volume,Change,ma5,ma10,ma20,Kospi,S&P500,rsi,%K,%D,bb_upper,bb_sma,bb_lower,volume_ma5,momentum,high_low_diff

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, GRU, Dense, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import Huber
from itertools import combinations
from tensorflow.keras.models import load_model


scaler = MinMaxScaler()
use_cols = ['Open', 'High', 'Low','Close','Volume']

colList = ['ma10', 'ma20', 'S&P500', 'Kospi', 'rsi', '%K', '%D', 'bb_upper', 'bb_lower', 'volume_ma5', 'momentum', 'high_low_diff']
result_pridict = []
com_colList = []

for r in range(2,3):
    for combination in combinations(colList, r):
        com_colList.append(list(combination))

for plus_cols in com_colList:
    use_cols.extend(plus_cols)

    scaled = scaler.fit_transform(stock[use_cols])
    df = pd.DataFrame(scaled, columns=use_cols)

    ln_use_cols = len(use_cols)
    WINDOW_SIZE = 20
    BATCH_SIZE = 100

    X, y = [], []

    for i in range(WINDOW_SIZE, len(scaled)):
        X.append(scaled[i - WINDOW_SIZE:i])
        y.append([scaled[i]])

    X, y = np.array(X), np.array(y)

    split_ratio = 0.8
    split_index = int(split_ratio * len(X))

    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]

    # LSTM 모델 정의
    lstm_input = Input(shape=(WINDOW_SIZE, ln_use_cols), name='lstm_input')
    lstm_layer = LSTM(64, activation='tanh')(lstm_input)

    # GRU 모델 정의
    gru_input = Input(shape=(WINDOW_SIZE, ln_use_cols), name='gru_input')
    gru_layer = GRU(64, activation='tanh')(gru_input)

    # 두 모델을 결합
    concatenated = concatenate([lstm_layer, gru_layer])

    # 공통 레이어 추가
    dense_layer = Dense(32, activation='relu')(concatenated)

    # 출력 레이어
    output = Dense(ln_use_cols, name='output')(dense_layer)

    # 모델 생성
    model = Model(inputs=[lstm_input, gru_input], outputs=output)

    loss = Huber()
    optimizer = Adam(learning_rate=0.001)
    model.compile(loss=loss, optimizer=optimizer)

    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    tmp = '_'.join(use_cols[5:])
    checkpoint = ModelCheckpoint(
        filepath=f'./checkpoint/LSTM_GRU//LSTM_GRU_{tmp}.h5',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    # 모델 학습
    history = model.fit(
        {'lstm_input': X_train, 'gru_input': X_train},  # 입력을 딕셔너리로 지정
        y_train,
        validation_split=0.2,
        epochs=50,
        callbacks=[early_stopping, checkpoint],
        batch_size=32
    )


    input_scaled = stock[use_cols]

    # 예측을 수행할 데이터
    total_data = [[input_scaled[len(input_scaled)-WINDOW_SIZE-1:len(input_scaled)-1]]]
    conform_total_data = [[input_scaled[len(input_scaled)-1:len(input_scaled)]]][:4]
    # print(total_data, 'total_data')
    data = np.array(total_data)
    data = data.tolist()
    data = data[0]
    # print(data, 'data')
    conform_data = conform_total_data[0][0]
    conform_data = conform_data.values[0]

    data_2d = np.array(data).reshape(-1, len(data[0][0]))

    # print(data_2d, "data_2d")
    scaler = MinMaxScaler()
    scaler.fit(data_2d)

    scaled_data_2d = scaler.transform(data_2d)
    model = load_model(f'./checkpoint/LSTM_GRU/LSTM_GRU_{tmp}.h5')
    scaled_data_3d = scaled_data_2d.reshape(len(data), len(data[0]), len(data[0][0]))
    print(conform_total_data , "conform_total_data")
    predicted_value = model.predict({'lstm_input': scaled_data_3d, 'gru_input': scaled_data_3d})
    print(predicted_value,'predicted_value')
    predicted_value_original = scaler.inverse_transform(predicted_value)
    predicted_value_original = np.round(predicted_value_original, ln_use_cols)[0][:4]
    print(predicted_value_original,"predicted_value_original")
    conform_total_data = conform_total_data[0][0].values[0]
    predicted_value_original = list(predicted_value_original)
    predicted_value_original.extend(conform_total_data[:4])
    use_cols_check = '/'.join(use_cols)
    predicted_value_original.append(use_cols_check)
    result_use_cols = use_cols[:4]
    result_use_cols.extend(['_Open', '_High', '_Low', '_Close', 'Use_Cols_Check'])

    result_dict = dict(zip(result_use_cols, predicted_value_original))
    result_pridict.append(result_dict)
    print(result_pridict)
    use_cols = use_cols[:5]  # 초기 use_cols로 재설정
# Out:
# Epoch 1/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 1: val_loss improved from inf to 0.00153, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 19s 16ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 2/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 2: val_loss improved from 0.00153 to 0.00147, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 3/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 3: val_loss improved from 0.00147 to 0.00145, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 4/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 4: val_loss improved from 0.00145 to 0.00144, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 5/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 5: val_loss did not improve from 0.00144
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 6/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 6: val_loss did not improve from 0.00144
# 992/992 [==============================] - 19s 20ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 7/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 7: val_loss did not improve from 0.00144
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 8/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 8: val_loss did not improve from 0.00144
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 9: val_loss did not improve from 0.00144
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 10/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 10: val_loss improved from 0.00144 to 0.00143, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 11/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 11: val_loss did not improve from 0.00143
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 12/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 12: val_loss did not improve from 0.00143
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 13/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 13: val_loss did not improve from 0.00143
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0016
# Epoch 14/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 14: val_loss improved from 0.00143 to 0.00142, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 15/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 15: val_loss did not improve from 0.00142
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 16/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 16: val_loss did not improve from 0.00142
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 17/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 17: val_loss did not improve from 0.00142
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 18/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 18: val_loss did not improve from 0.00142
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 19/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 19: val_loss did not improve from 0.00142
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 20/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 20: val_loss did not improve from 0.00142
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 21/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 21: val_loss did not improve from 0.00142
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 22/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 22: val_loss did not improve from 0.00142
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 23/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 23: val_loss did not improve from 0.00142
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 24/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 24: val_loss did not improve from 0.00142
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 25/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 25: val_loss improved from 0.00142 to 0.00141, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 26/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 26: val_loss improved from 0.00141 to 0.00141, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_ma20.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 27/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 27: val_loss did not improve from 0.00141
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 28/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 28: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 29/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 29: val_loss did not improve from 0.00141
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 30/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 30: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 31/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 31: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 32/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 32: val_loss did not improve from 0.00141
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 33/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 33: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 34/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 34: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 35/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 35: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 36/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 36: val_loss did not improve from 0.00141
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 37/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 37: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 38/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 38: val_loss did not improve from 0.00141
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 39/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 39: val_loss did not improve from 0.00141
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 40/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 40: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 41/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 41: val_loss did not improve from 0.00141
# 992/992 [==============================] - 19s 20ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 42/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 42: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 43/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 43: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 44/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 44: val_loss did not improve from 0.00141
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 45/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 45: val_loss did not improve from 0.00141
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 46/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 46: val_loss did not improve from 0.00141
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0071 - val_loss: 0.0014
# [[         Open    High     Low   Close  Volume      ma10      ma20
# 49584  947776  947776  885513  892432  175056  896483.7  894606.0]] conform_total_data
# 1/1 [==============================] - 2s 2s/step
# [[0.07533745 0.08217679 0.08575693 0.08587103 0.0030723  0.09961177
#   0.09018213]] predicted_value
# [872075.75 887651.1  847029.75 869093.44] predicted_value_original
# [{'Open': 872075.75, 'High': 887651.1, 'Low': 847029.75, 'Close': 869093.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/ma20'}]
# Epoch 1/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 1: val_loss improved from inf to 0.00456, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_S&P500.h5
# 992/992 [==============================] - 25s 20ms/step - loss: 0.0087 - val_loss: 0.0046
# Epoch 2/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 2: val_loss improved from 0.00456 to 0.00450, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_S&P500.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0087 - val_loss: 0.0045
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 3: val_loss improved from 0.00450 to 0.00447, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_S&P500.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0087 - val_loss: 0.0045
# Epoch 4/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 4: val_loss did not improve from 0.00447
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 5/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 5: val_loss improved from 0.00447 to 0.00443, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_S&P500.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0044
# Epoch 6/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 6: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 7: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 8/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 8: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 9/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 9: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 10/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 10: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 11/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 11: val_loss did not improve from 0.00443
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 12/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 12: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 13/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 13: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 14/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 14: val_loss did not improve from 0.00443
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 15/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 15: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 16/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 16: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 17/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 17: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 18/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 18: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 19/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 19: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 20/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 20: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 21/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 21: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0046
# Epoch 22/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 22: val_loss did not improve from 0.00443
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 23/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 23: val_loss did not improve from 0.00443
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 24/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 24: val_loss did not improve from 0.00443
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0086 - val_loss: 0.0044
# Epoch 25/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 25: val_loss did not improve from 0.00443
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0086 - val_loss: 0.0045
# [[         Open    High     Low   Close  Volume      ma10      S&P500
# 49584  947776  947776  885513  892432  175056  896483.7  4778.72998]] conform_total_data
# 1/1 [==============================] - 2s 2s/step
# [[0.11606414 0.09716289 0.12940864 0.10765161 0.02088412 0.08303037
#   0.2775305 ]] predicted_value
# [875497.  888761.9 851085.1 870944.6] predicted_value_original
# [{'Open': 872075.75, 'High': 887651.1, 'Low': 847029.75, 'Close': 869093.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/ma20'}, {'Open': 875497.0, 'High': 888761.9, 'Low': 851085.1, 'Close': 870944.6, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/S&P500'}]
# Epoch 1/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 1: val_loss improved from inf to 0.00441, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_Kospi.h5
# 992/992 [==============================] - 32s 19ms/step - loss: 0.0097 - val_loss: 0.0044
# Epoch 2/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 2: val_loss did not improve from 0.00441
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0096 - val_loss: 0.0045
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 3: val_loss improved from 0.00441 to 0.00431, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_Kospi.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 4/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 4: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 5/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 5: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 6/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 6: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0046
# Epoch 7/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 7: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 8: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 9: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 10/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 10: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 11/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 11: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 12/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 12: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 13/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 13: val_loss did not improve from 0.00431
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 14/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 14: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 15/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 15: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 16/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 16: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 17/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 17: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 18/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 18: val_loss did not improve from 0.00431
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 19/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 19: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 20/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 20: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 21/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 21: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 22/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 22: val_loss did not improve from 0.00431
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 23/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 23: val_loss did not improve from 0.00431
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0095 - val_loss: 0.0043
# [[         Open    High     Low   Close  Volume      ma10        Kospi
# 49584  947776  947776  885513  892432  175056  896483.7  2977.649902]] conform_total_data
# 1/1 [==============================] - 2s 2s/step
# [[0.09034684 0.173273   0.08999647 0.11795433 0.01248329 0.14122128
#   0.5569497 ]] predicted_value
# [873336.56 894403.4  847423.7  871820.3 ] predicted_value_original
# [{'Open': 872075.75, 'High': 887651.1, 'Low': 847029.75, 'Close': 869093.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/ma20'}, {'Open': 875497.0, 'High': 888761.9, 'Low': 851085.1, 'Close': 870944.6, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/S&P500'}, {'Open': 873336.56, 'High': 894403.4, 'Low': 847423.7, 'Close': 871820.3, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/Kospi'}]
# Epoch 1/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 1: val_loss improved from inf to 0.00300, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_rsi.h5
# 992/992 [==============================] - 29s 20ms/step - loss: 0.0082 - val_loss: 0.0030
# Epoch 2/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 2: val_loss improved from 0.00300 to 0.00292, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_rsi.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 3: val_loss did not improve from 0.00292
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 4/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 4: val_loss did not improve from 0.00292
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 5/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 5: val_loss did not improve from 0.00292
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 6/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 6: val_loss did not improve from 0.00292
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 7/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 7: val_loss did not improve from 0.00292
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 8/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 8: val_loss did not improve from 0.00292
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 9: val_loss improved from 0.00292 to 0.00291, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_rsi.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 10/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 10: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 11/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 11: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 12/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 12: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 13/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 13: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 14/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 14: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 15/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 15: val_loss did not improve from 0.00291
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 16/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 16: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 17/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 17: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 18/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 18: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 19/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 19: val_loss did not improve from 0.00291
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 20/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 20: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 21/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 21: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 22/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 22: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 23/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 23: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 24/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 24: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 25/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 25: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 26/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 26: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 27/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 27: val_loss did not improve from 0.00291
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 28/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 28: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 29/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 29: val_loss did not improve from 0.00291
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0078 - val_loss: 0.0030
# [[         Open    High     Low   Close  Volume      ma10       rsi
# 49584  947776  947776  885513  892432  175056  896483.7  47.05877]] conform_total_data
# 1/1 [==============================] - 1s 1s/step
# [[0.07770682 0.09747475 0.08936325 0.07961103 0.03694327 0.08203249
#   0.48505872]] predicted_value
# [872274.75 888785.06 847364.9  868561.4 ] predicted_value_original
# [{'Open': 872075.75, 'High': 887651.1, 'Low': 847029.75, 'Close': 869093.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/ma20'}, {'Open': 875497.0, 'High': 888761.9, 'Low': 851085.1, 'Close': 870944.6, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/S&P500'}, {'Open': 873336.56, 'High': 894403.4, 'Low': 847423.7, 'Close': 871820.3, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/Kospi'}, {'Open': 872274.75, 'High': 888785.06, 'Low': 847364.9, 'Close': 868561.4, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/rsi'}]
# Epoch 1/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 1: val_loss improved from inf to 0.00598, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%K.h5
# 992/992 [==============================] - 30s 20ms/step - loss: 0.0110 - val_loss: 0.0060
# Epoch 2/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 2: val_loss improved from 0.00598 to 0.00594, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%K.h5
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 3/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 3: val_loss did not improve from 0.00594
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 4/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 4: val_loss did not improve from 0.00594
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 5/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 5: val_loss improved from 0.00594 to 0.00592, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%K.h5
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 6/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 6: val_loss did not improve from 0.00592
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 7: val_loss improved from 0.00592 to 0.00591, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%K.h5
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 8/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 8: val_loss did not improve from 0.00591
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 9: val_loss did not improve from 0.00591
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 10/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 10: val_loss did not improve from 0.00591
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 11/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 11: val_loss improved from 0.00591 to 0.00590, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%K.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 12/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 12: val_loss improved from 0.00590 to 0.00589, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%K.h5
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 13/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 13: val_loss did not improve from 0.00589
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 14/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 14: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 15/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 15: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 16/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 16: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 20ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 17/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 17: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 18/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 18: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 19/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 19: val_loss did not improve from 0.00589
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 20/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 20: val_loss did not improve from 0.00589
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0061
# Epoch 21/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 21: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 22/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 22: val_loss did not improve from 0.00589
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 23/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 23: val_loss did not improve from 0.00589
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 24/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 24: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 25/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 25: val_loss did not improve from 0.00589
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 26/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 26: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 27/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 27: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 28/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 28: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 29/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 29: val_loss did not improve from 0.00589
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 30/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 30: val_loss did not improve from 0.00589
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0108 - val_loss: 0.0060
# Epoch 31/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 31: val_loss did not improve from 0.00589
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0108 - val_loss: 0.0059
# Epoch 32/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 32: val_loss did not improve from 0.00589
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0108 - val_loss: 0.0060
# [[         Open    High     Low   Close  Volume      ma10         %K
# 49584  947776  947776  885513  892432  175056  896483.7  33.334036]] conform_total_data
# 1/1 [==============================] - 1s 1s/step
# [[0.09723459 0.09230899 0.0828508  0.08346083 0.01118206 0.10299365
#   0.44025373]] predicted_value
# [873915.25 888402.1  846759.8  868888.56] predicted_value_original
# [{'Open': 872075.75, 'High': 887651.1, 'Low': 847029.75, 'Close': 869093.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/ma20'}, {'Open': 875497.0, 'High': 888761.9, 'Low': 851085.1, 'Close': 870944.6, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/S&P500'}, {'Open': 873336.56, 'High': 894403.4, 'Low': 847423.7, 'Close': 871820.3, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/Kospi'}, {'Open': 872274.75, 'High': 888785.06, 'Low': 847364.9, 'Close': 868561.4, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/rsi'}, {'Open': 873915.25, 'High': 888402.1, 'Low': 846759.8, 'Close': 868888.56, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/%K'}]
# Epoch 1/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 1: val_loss improved from inf to 0.00621, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%D.h5
# 992/992 [==============================] - 33s 21ms/step - loss: 0.0113 - val_loss: 0.0062
# Epoch 2/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 2: val_loss improved from 0.00621 to 0.00615, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%D.h5
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 3: val_loss did not improve from 0.00615
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 4/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 4: val_loss did not improve from 0.00615
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 5/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 5: val_loss did not improve from 0.00615
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 6/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 6: val_loss did not improve from 0.00615
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 7/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 7: val_loss did not improve from 0.00615
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 8/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 8: val_loss did not improve from 0.00615
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 9/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 9: val_loss improved from 0.00615 to 0.00612, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%D.h5
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 10/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 10: val_loss did not improve from 0.00612
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 11/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 11: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 12/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 12: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 13/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 13: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 14/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 14: val_loss did not improve from 0.00612
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 15/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 15: val_loss did not improve from 0.00612
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 16/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 16: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0063
# Epoch 17/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 17: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 18/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 18: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 19/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 19: val_loss did not improve from 0.00612
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 20/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 20: val_loss did not improve from 0.00612
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 21/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 21: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 22/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 22: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 23/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 23: val_loss did not improve from 0.00612
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 24/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 24: val_loss improved from 0.00612 to 0.00611, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma10_%D.h5
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 25/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 25: val_loss did not improve from 0.00611
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 26/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 26: val_loss did not improve from 0.00611
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 27/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 27: val_loss did not improve from 0.00611
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 28/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 28: val_loss did not improve from 0.00611
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 29/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 29: val_loss did not improve from 0.00611
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 30/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 30: val_loss did not improve from 0.00611
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 31/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 31: val_loss did not improve from 0.00611
# 992/992 [==============================] - 19s 20ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 32/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 32: val_loss did not improve from 0.00611
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 33/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 33: val_loss did not improve from 0.00611
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 34/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 34: val_loss did not improve from 0.00611
# 992/992 [==============================] - 19s 19ms/step - loss: 0.0111 - val_loss: 0.0063
# Epoch 35/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 35: val_loss did not improve from 0.00611
# 992/992 [==============================] - 18s 19ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 36/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 36: val_loss did not improve from 0.00611
# ...
# Epoch 10/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 10: val_loss did not improve from 0.00606
# 992/992 [==============================] - 20s 20ms/step - loss: 0.0112 - val_loss: 0.0061
# Epoch 11/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 11: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 12/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 12: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 13/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 13: val_loss did not improve from 0.00606
# 992/992 [==============================] - 18s 18ms/step - loss: 0.0112 - val_loss: 0.0063
# Epoch 14/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 14: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 18ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 15/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 15: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0112 - val_loss: 0.0063
# Epoch 16/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 16: val_loss did not improve from 0.00606
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 17/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 17: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 18/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 18: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 19/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 19: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 20/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 20: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 21/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 21: val_loss did not improve from 0.00606
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 22/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 22: val_loss did not improve from 0.00606
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 23/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 23: val_loss did not improve from 0.00606
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0112 - val_loss: 0.0062
# Epoch 24/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 24: val_loss did not improve from 0.00606
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0112 - val_loss: 0.0062
# [[         Open    High     Low   Close  Volume      ma20         %D
# 49584  947776  947776  885513  892432  175056  894606.0  24.653232]] conform_total_data
# 1/1 [==============================] - 1s 1s/step
# [[0.09603768 0.10238665 0.07360481 0.10742535 0.02225139 0.10828103
#   0.5544214 ]] predicted_value
# [873814.7  889149.06 845900.9  870925.44] predicted_value_original
# [{'Open': 872075.75, 'High': 887651.1, 'Low': 847029.75, 'Close': 869093.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/ma20'}, {'Open': 875497.0, 'High': 888761.9, 'Low': 851085.1, 'Close': 870944.6, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/S&P500'}, {'Open': 873336.56, 'High': 894403.4, 'Low': 847423.7, 'Close': 871820.3, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/Kospi'}, {'Open': 872274.75, 'High': 888785.06, 'Low': 847364.9, 'Close': 868561.4, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/rsi'}, {'Open': 873915.25, 'High': 888402.1, 'Low': 846759.8, 'Close': 868888.56, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/%K'}, {'Open': 874101.3, 'High': 888487.94, 'Low': 847609.1, 'Close': 870819.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/%D'}, {'Open': 870988.44, 'High': 889590.5, 'Low': 844961.7, 'Close': 867068.5, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/bb_upper'}, {'Open': 874078.0, 'High': 886720.3, 'Low': 849292.9, 'Close': 867987.75, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/bb_lower'}, {'Open': 873490.75, 'High': 887099.7, 'Low': 846823.2, 'Close': 869633.56, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/volume_ma5'}, {'Open': 879278.8, 'High': 886100.06, 'Low': 849552.6, 'Close': 865344.5, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/momentum'}, {'Open': 877503.56, 'High': 885271.5, 'Low': 844984.6, 'Close': 868952.4, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/high_low_diff'}, {'Open': 871342.0, 'High': 889063.5, 'Low': 848682.1, 'Close': 870329.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/S&P500'}, {'Open': 873042.4, 'High': 889807.6, 'Low': 849750.4, 'Close': 869543.94, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/Kospi'}, {'Open': 871045.3, 'High': 891085.3, 'Low': 848936.75, 'Close': 870306.06, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/rsi'}, {'Open': 874696.75, 'High': 890116.1, 'Low': 846614.9, 'Close': 867915.25, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/%K'}, {'Open': 873814.7, 'High': 889149.06, 'Low': 845900.9, 'Close': 870925.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/%D'}]
# Epoch 1/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 1: val_loss improved from inf to 0.00145, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma20_bb_upper.h5
# 992/992 [==============================] - 24s 17ms/step - loss: 0.0072 - val_loss: 0.0015
# Epoch 2/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 2: val_loss improved from 0.00145 to 0.00136, saving model to ./checkpoint/LSTM_GRU\LSTM_GRU_ma20_bb_upper.h5
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 3/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 3: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 4/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 4: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 5/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 5: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 6/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 6: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 7/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 7: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 8/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 8: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 9/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 9: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 10/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 10: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 11/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 11: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 12/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 12: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 13/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 13: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 14/50
# 990/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 14: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 15/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 15: val_loss did not improve from 0.00136
# 992/992 [==============================] - 14s 14ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 16/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 16: val_loss did not improve from 0.00136
# 992/992 [==============================] - 15s 15ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 17/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 17: val_loss did not improve from 0.00136
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 18/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 18: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 19/50
# 991/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 19: val_loss did not improve from 0.00136
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 20/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 20: val_loss did not improve from 0.00136
# 992/992 [==============================] - 17s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 21/50
# 989/992 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 21: val_loss did not improve from 0.00136
# 992/992 [==============================] - 16s 16ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 22/50
# 992/992 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 22: val_loss did not improve from 0.00136
# 992/992 [==============================] - 16s 17ms/step - loss: 0.0071 - val_loss: 0.0015
# [[         Open    High     Low   Close  Volume      ma20       bb_upper
# 49584  947776  947776  885513  892432  175056  894606.0  940724.272154]] conform_total_data
# 1/1 [==============================] - 3s 3s/step
# [[0.05534179 0.05997396 0.11277281 0.12093169 0.02953244 0.06095439
#   0.08278637]] predicted_value
# [870396.  886005.4 849539.6 872073.4] predicted_value_original
# [{'Open': 872075.75, 'High': 887651.1, 'Low': 847029.75, 'Close': 869093.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/ma20'}, {'Open': 875497.0, 'High': 888761.9, 'Low': 851085.1, 'Close': 870944.6, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/S&P500'}, {'Open': 873336.56, 'High': 894403.4, 'Low': 847423.7, 'Close': 871820.3, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/Kospi'}, {'Open': 872274.75, 'High': 888785.06, 'Low': 847364.9, 'Close': 868561.4, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/rsi'}, {'Open': 873915.25, 'High': 888402.1, 'Low': 846759.8, 'Close': 868888.56, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/%K'}, {'Open': 874101.3, 'High': 888487.94, 'Low': 847609.1, 'Close': 870819.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/%D'}, {'Open': 870988.44, 'High': 889590.5, 'Low': 844961.7, 'Close': 867068.5, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/bb_upper'}, {'Open': 874078.0, 'High': 886720.3, 'Low': 849292.9, 'Close': 867987.75, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/bb_lower'}, {'Open': 873490.75, 'High': 887099.7, 'Low': 846823.2, 'Close': 869633.56, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/volume_ma5'}, {'Open': 879278.8, 'High': 886100.06, 'Low': 849552.6, 'Close': 865344.5, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/momentum'}, {'Open': 877503.56, 'High': 885271.5, 'Low': 844984.6, 'Close': 868952.4, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma10/high_low_diff'}, {'Open': 871342.0, 'High': 889063.5, 'Low': 848682.1, 'Close': 870329.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/S&P500'}, {'Open': 873042.4, 'High': 889807.6, 'Low': 849750.4, 'Close': 869543.94, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/Kospi'}, {'Open': 871045.3, 'High': 891085.3, 'Low': 848936.75, 'Close': 870306.06, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/rsi'}, {'Open': 874696.75, 'High': 890116.1, 'Low': 846614.9, 'Close': 867915.25, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/%K'}, {'Open': 873814.7, 'High': 889149.06, 'Low': 845900.9, 'Close': 870925.44, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/%D'}, {'Open': 870396.0, 'High': 886005.4, 'Low': 849539.6, 'Close': 872073.4, '_Open': 947776.0, '_High': 947776.0, '_Low': 885513.0, '_Close': 892432.0, 'Use_Cols_Check': 'Open/High/Low/Close/Volume/ma20/bb_upper'}]
# Epoch 1/50
#  12/992 [..............................] - ETA: 13s - loss: 0.0096

# %%
print(result_pridict)
import pandas as pd


# 데이터를 DataFrame으로 변환
df = pd.DataFrame(result_pridict)

# DataFrame을 엑셀 파일로 저장
df.to_excel('Ensemble_predict2.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\SSAFY\Desktop\S09P31C106\AI\TH\learning\LSTM_GRU_Learing.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/learning/LSTM_GRU_Learing.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> print(result_pridict)
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/learning/LSTM_GRU_Learing.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/learning/LSTM_GRU_Learing.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> # 데이터를 DataFrame으로 변환
#
# NameError: name 'result_pridict' is not defined
