# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import glob

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# CSV 파일들을 저장할 빈 DataFrame을 생성합니다.


# data 폴더에 있는 모든 CSV 파일을 가져옵니다.
csv_files = glob.glob('./high50data/*.csv')
print(csv_files)
# Out:
# ['./high50data\\000270.csv', './high50data\\000660.csv', './high50data\\000810.csv', './high50data\\003550.csv', './high50data\\003670.csv', './high50data\\005380.csv', './high50data\\005490.csv', './high50data\\005930.csv', './high50data\\005935.csv', './high50data\\006400.csv', './high50data\\009150.csv', './high50data\\010130.csv', './high50data\\012330.csv', './high50data\\015760.csv', './high50data\\017670.csv', './high50data\\018260.csv', './high50data\\024110.csv', './high50data\\028260.csv', './high50data\\032830.csv', './high50data\\033780.csv', './high50data\\034020.csv', './high50data\\034730.csv', './high50data\\035420.csv', './high50data\\035720.csv', './high50data\\047050.csv', './high50data\\051910.csv', './high50data\\055550.csv', './high50data\\066570.csv', './high50data\\068270.csv', './high50data\\086790.csv', './high50data\\096770.csv', './high50data\\105560.csv', './high50data\\138040.csv', './high50data\\207940.csv', './high50data\\316140.csv', './high50data\\323410.csv', './high50data\\329180.csv', './high50data\\352820.csv']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
import pandas as pd

from tf.keras.models import Sequential
from tf.keras.layers import GRU, Dense, Dropout
from tf.keras.optimizers import Adam
from tf.keras.callbacks import EarlyStopping, ModelCheckpoint
from tf.keras.losses import Huber, MeanAbsoluteError
from tf.keras.models import load_model
from tf.keras.models import Model
from tf.keras.optimizers import AdamW

# 데이터 파일 경로 설정 (csv_files 변수에 파일 경로 리스트를 할당해야 합니다)

stock_num_li = ['005930', '000660', '207940', '005935', '005380', '005490', '000270', '051910', '035420', '006400', '068270', '105560', '012330', '003670', '028260', '055550', '066570', '035720', '032830', '096770', '003550', '086790', '000810','033780', '017670', '015760', '138040', '034730', '009150', '018260', '329180', '010130', '047050', '323410', '316140', '024110', '034020', '352820']
normal = 'Open High Low Close Volume '
M1 = 'ma10'
DU = 'high_low_diff bb_upper'
M1SP = 'ma10 S&P500'
M2VM = 'ma20 volumn_ma5'
SPU = 'S&P500 bb_upper'
M1K = 'ma10 %K'
M2SP = 'ma20 S&P500'
KOU = 'Kospi bb_upper'
KSPU = 'Kospi S&P500 bb_upper'
colset_list = [KSPU, M1, DU, M1SP, SPU, M1K, M2SP, KOU]
WINDOW_SIZE = 50
BATCH_SIZE = WINDOW_SIZE * 2
epoch_size = 10
patience = 5
learning_rate = 0.01

# 주식별로 학습 및 예측 실행
result_pridict = []
scaler = MinMaxScaler()
# 공통 데이터 로딩 및 전처리 함수
def load_and_preprocess_data(stock_num, colset, WINDOW_SIZE):
    stock = pd.DataFrame()
    file_path = [csv for csv in csv_files if f'./high50data\\{stock_num}.csv' in csv][0]
    df = pd.read_csv(file_path)
    stock = pd.concat([stock, df], ignore_index=True)
    
    tmp_use_col = normal + colset
    colset = colset.replace(" ", "_")
    use_cols = tmp_use_col.split()
    ln_use_cols = len(use_cols)
    
    scaled = scaler.fit_transform(stock[use_cols])
    df = pd.DataFrame(scaled, columns=use_cols)
    
    X, y = [], []
    
    for i in range(WINDOW_SIZE, len(scaled)):
        X.append(scaled[i - WINDOW_SIZE:i])
        y.append([scaled[i][3]])  # Close 열만 학습
    X, y = np.array(X), np.array(y)
    
    split_ratio = 0.8
    split_index = int(split_ratio * len(X))
    
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    return X_train, X_test, y_train, y_test, use_cols, ln_use_cols

# 학습 함수
def train_model(X_train, y_train, use_cols, checkpoint_path, WINDOW_SIZE, learning_rate=0.01, epoch_size=30, patience=5):
    model = Sequential([
        GRU(32, activation='tanh', input_shape=(WINDOW_SIZE, len(use_cols))),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dropout(0.2),
        Dense(len(use_cols))
    ])

    loss = Huber()
    optimizer = AdamW(
        learning_rate=learning_rate,
        weight_decay=0.004,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-07,
        amsgrad=False,
        clipnorm=None,
        clipvalue=None,
        global_clipnorm=None,
        use_ema=False,
        ema_momentum=0.99,
        name="AdamW",
    )

    model.compile(loss=loss, optimizer=optimizer, metrics=[MeanAbsoluteError()])

    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    checkpoint = ModelCheckpoint(
        filepath=checkpoint_path,
        monitor='val_loss',
        save_best_only=True,
        verbose=1,
    )

    history = model.fit(
        X_train,
        y_train,
        validation_split=0.2,
        epochs=epoch_size,
        callbacks=[early_stopping, checkpoint],
        batch_size=BATCH_SIZE
    )

# 예측 및 모델 저장 함수
def predict_and_save_model(stock_num, use_cols, WINDOW_SIZE):
    X_train, _, y_train, _, use_cols, ln_use_cols = load_and_preprocess_data(stock_num, use_cols, WINDOW_SIZE)
    
    checkpoint_path = f'./checkpoint/GRU/AdamW/{WINDOW_SIZE}/{stock_num}_{use_cols[5:]}_{WINDOW_SIZE}.h5'
    
    train_model(X_train, y_train, use_cols, checkpoint_path, WINDOW_SIZE, learning_rate, epoch_size, patience)
    
    model = load_model(checkpoint_path, custom_objects={'MeanAbsoluteError': MeanAbsoluteError()})
    
    # 데이터 다시 로딩
    stock = pd.DataFrame()
    file_path = [csv for csv in csv_files if f'./high50data\\{stock_num}.csv' in csv][0]
    df = pd.read_csv(file_path)
    stock = pd.concat([stock, df], ignore_index=True)

    input_scaled = stock[use_cols]
    total_data = [[input_scaled[len(input_scaled)-WINDOW_SIZE-1:len(input_scaled)-1]]]
    conform_total_data = [[input_scaled[len(input_scaled)-1:len(input_scaled)]]][:4]
    
    data = np.array(total_data)
    data = data.tolist()
    data = data[0]
    
    conform_data = conform_total_data[0][0]
    conform_data = conform_data.values[0]
    
    data_2d = np.array(data).reshape(-1, len(data[0][0]))
    
    scaler = MinMaxScaler()
    scaler.fit(data_2d)
    
    scaled_data_2d = scaler.transform(data_2d)
    
    scaled_data_3d = scaled_data_2d.reshape(len(data), len(data[0]), len(data[0][0]))
    
    model = load_model(checkpoint_path, custom_objects={'MeanAbsoluteError': MeanAbsoluteError()})
    
    predicted_value = model.predict(scaled_data_3d)
    
    # output_layer = model.get_layer(index=-1)
    
    # new_model = Model(inputs=model.input, outputs=output_layer.output)
    
    # predicted_value = new_model.predict(scaled_data_3d)
    
    print(predicted_value)
    predicted_value_original = scaler.inverse_transform(predicted_value)
    predicted_value_original = np.round(predicted_value_original, ln_use_cols)[0][:4]
    conform_total_data = conform_total_data[0][0].values[0]
    predicted_value_original = list(predicted_value_original)
    predicted_value_original.extend(conform_total_data[:4])
    
    use_cols_check = '/'.join(use_cols)
    predicted_value_original.append(use_cols_check)
    result_use_cols = use_cols[:4]
    result_use_cols.extend(['_Open', '_High', '_Low', '_Close', 'Use_Cols_Check'])
    
    result_dict = dict(zip(result_use_cols, predicted_value_original))
    result_pridict.append(result_dict)

for stock_num in stock_num_li:
    for colset in colset_list:
        predict_and_save_model(stock_num, colset, WINDOW_SIZE)
# Out:
# Epoch 1/30
# 34/34 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0426
# Epoch 1: val_loss improved from inf to 0.00067, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 6s 61ms/step - loss: 0.0020 - mean_absolute_error: 0.0426 - val_loss: 6.7377e-04 - val_mean_absolute_error: 0.0298
# Epoch 2/30
# 33/34 [============================>.] - ETA: 0s - loss: 5.4525e-04 - mean_absolute_error: 0.0224
# Epoch 2: val_loss improved from 0.00067 to 0.00021, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 34ms/step - loss: 5.3971e-04 - mean_absolute_error: 0.0223 - val_loss: 2.0706e-04 - val_mean_absolute_error: 0.0171
# Epoch 3/30
# 33/34 [============================>.] - ETA: 0s - loss: 4.0419e-04 - mean_absolute_error: 0.0190
# Epoch 3: val_loss did not improve from 0.00021
# 34/34 [==============================] - 1s 35ms/step - loss: 4.0180e-04 - mean_absolute_error: 0.0190 - val_loss: 4.9394e-04 - val_mean_absolute_error: 0.0300
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 3.3664e-04 - mean_absolute_error: 0.0172
# Epoch 4: val_loss improved from 0.00021 to 0.00007, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 3.3664e-04 - mean_absolute_error: 0.0172 - val_loss: 7.4522e-05 - val_mean_absolute_error: 0.0101
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 3.0277e-04 - mean_absolute_error: 0.0162
# Epoch 5: val_loss did not improve from 0.00007
# 34/34 [==============================] - 1s 29ms/step - loss: 3.0277e-04 - mean_absolute_error: 0.0162 - val_loss: 2.2813e-04 - val_mean_absolute_error: 0.0188
# Epoch 6/30
# 34/34 [==============================] - ETA: 0s - loss: 2.9641e-04 - mean_absolute_error: 0.0164
# Epoch 6: val_loss did not improve from 0.00007
# 34/34 [==============================] - 1s 26ms/step - loss: 2.9641e-04 - mean_absolute_error: 0.0164 - val_loss: 3.7398e-04 - val_mean_absolute_error: 0.0258
# Epoch 7/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.0598e-04 - mean_absolute_error: 0.0165
# Epoch 7: val_loss did not improve from 0.00007
# 34/34 [==============================] - 1s 27ms/step - loss: 3.0490e-04 - mean_absolute_error: 0.0165 - val_loss: 1.8357e-04 - val_mean_absolute_error: 0.0172
# Epoch 8/30
# 32/34 [===========================>..] - ETA: 0s - loss: 3.3326e-04 - mean_absolute_error: 0.0176
# Epoch 8: val_loss improved from 0.00007 to 0.00004, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 29ms/step - loss: 3.3114e-04 - mean_absolute_error: 0.0175 - val_loss: 4.2199e-05 - val_mean_absolute_error: 0.0076
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 2.5219e-04 - mean_absolute_error: 0.0148
# Epoch 9: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 35ms/step - loss: 2.5219e-04 - mean_absolute_error: 0.0148 - val_loss: 1.3769e-04 - val_mean_absolute_error: 0.0144
# Epoch 10/30
# 32/34 [===========================>..] - ETA: 0s - loss: 2.5511e-04 - mean_absolute_error: 0.0152
# Epoch 10: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 33ms/step - loss: 2.5259e-04 - mean_absolute_error: 0.0153 - val_loss: 7.8938e-05 - val_mean_absolute_error: 0.0102
# Epoch 11/30
# 34/34 [==============================] - ETA: 0s - loss: 2.6722e-04 - mean_absolute_error: 0.0156
# Epoch 11: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 27ms/step - loss: 2.6722e-04 - mean_absolute_error: 0.0156 - val_loss: 6.9064e-04 - val_mean_absolute_error: 0.0361
# Epoch 12/30
# 33/34 [============================>.] - ETA: 0s - loss: 2.3466e-04 - mean_absolute_error: 0.0145
# Epoch 12: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 28ms/step - loss: 2.3477e-04 - mean_absolute_error: 0.0145 - val_loss: 1.3538e-04 - val_mean_absolute_error: 0.0136
# Epoch 13/30
# 34/34 [==============================] - ETA: 0s - loss: 2.4645e-04 - mean_absolute_error: 0.0146
# Epoch 13: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 26ms/step - loss: 2.4645e-04 - mean_absolute_error: 0.0146 - val_loss: 3.6468e-04 - val_mean_absolute_error: 0.0258
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 332ms/step
# [[0.7343927  0.7391507  0.72497433 0.7258961  0.7246133  0.7114663
#   0.71957487 0.68522286]]
# Epoch 1/30
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019 - mean_absolute_error: 0.0403
# Epoch 1: val_loss improved from inf to 0.00064, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_50.h5
# 34/34 [==============================] - 5s 40ms/step - loss: 0.0019 - mean_absolute_error: 0.0399 - val_loss: 6.4205e-04 - val_mean_absolute_error: 0.0305
# Epoch 2/30
# 34/34 [==============================] - ETA: 0s - loss: 5.2507e-04 - mean_absolute_error: 0.0211
# Epoch 2: val_loss improved from 0.00064 to 0.00018, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_50.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 5.2507e-04 - mean_absolute_error: 0.0211 - val_loss: 1.7967e-04 - val_mean_absolute_error: 0.0161
# Epoch 3/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.8704e-04 - mean_absolute_error: 0.0180
# Epoch 3: val_loss did not improve from 0.00018
# 34/34 [==============================] - 1s 26ms/step - loss: 3.8356e-04 - mean_absolute_error: 0.0179 - val_loss: 1.8371e-04 - val_mean_absolute_error: 0.0165
# Epoch 4/30
# 33/34 [============================>.] - ETA: 0s - loss: 4.0788e-04 - mean_absolute_error: 0.0188
# Epoch 4: val_loss did not improve from 0.00018
# 34/34 [==============================] - 1s 31ms/step - loss: 4.0781e-04 - mean_absolute_error: 0.0189 - val_loss: 3.7713e-04 - val_mean_absolute_error: 0.0255
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 3.2822e-04 - mean_absolute_error: 0.0170
# Epoch 5: val_loss did not improve from 0.00018
# 34/34 [==============================] - 1s 38ms/step - loss: 3.2822e-04 - mean_absolute_error: 0.0170 - val_loss: 3.1552e-04 - val_mean_absolute_error: 0.0237
# Epoch 6/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.1871e-04 - mean_absolute_error: 0.0170
# Epoch 6: val_loss improved from 0.00018 to 0.00012, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_50.h5
# 34/34 [==============================] - 1s 29ms/step - loss: 3.2011e-04 - mean_absolute_error: 0.0170 - val_loss: 1.2498e-04 - val_mean_absolute_error: 0.0138
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 3.0639e-04 - mean_absolute_error: 0.0157
# Epoch 7: val_loss did not improve from 0.00012
# 34/34 [==============================] - 1s 28ms/step - loss: 3.0639e-04 - mean_absolute_error: 0.0157 - val_loss: 2.7227e-04 - val_mean_absolute_error: 0.0212
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 3.2100e-04 - mean_absolute_error: 0.0162
# Epoch 8: val_loss did not improve from 0.00012
# 34/34 [==============================] - 1s 25ms/step - loss: 3.2100e-04 - mean_absolute_error: 0.0162 - val_loss: 3.5777e-04 - val_mean_absolute_error: 0.0253
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 3.1764e-04 - mean_absolute_error: 0.0165
# Epoch 9: val_loss improved from 0.00012 to 0.00010, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 3.1764e-04 - mean_absolute_error: 0.0165 - val_loss: 1.0275e-04 - val_mean_absolute_error: 0.0120
# Epoch 10/30
# 33/34 [============================>.] - ETA: 0s - loss: 2.7048e-04 - mean_absolute_error: 0.0153
# Epoch 10: val_loss did not improve from 0.00010
# 34/34 [==============================] - 1s 27ms/step - loss: 2.7596e-04 - mean_absolute_error: 0.0154 - val_loss: 2.3113e-04 - val_mean_absolute_error: 0.0192
# Epoch 11/30
# 34/34 [==============================] - ETA: 0s - loss: 2.7560e-04 - mean_absolute_error: 0.0156
# Epoch 11: val_loss did not improve from 0.00010
# 34/34 [==============================] - 1s 34ms/step - loss: 2.7560e-04 - mean_absolute_error: 0.0156 - val_loss: 1.8732e-04 - val_mean_absolute_error: 0.0182
# Epoch 12/30
# 34/34 [==============================] - ETA: 0s - loss: 2.9395e-04 - mean_absolute_error: 0.0159
# Epoch 12: val_loss did not improve from 0.00010
# 34/34 [==============================] - 1s 34ms/step - loss: 2.9395e-04 - mean_absolute_error: 0.0159 - val_loss: 4.0834e-04 - val_mean_absolute_error: 0.0275
# Epoch 13/30
# 33/34 [============================>.] - ETA: 0s - loss: 2.8536e-04 - mean_absolute_error: 0.0156
# Epoch 13: val_loss improved from 0.00010 to 0.00009, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_50.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 2.8741e-04 - mean_absolute_error: 0.0157 - val_loss: 8.7374e-05 - val_mean_absolute_error: 0.0109
# Epoch 14/30
# 32/34 [===========================>..] - ETA: 0s - loss: 2.7049e-04 - mean_absolute_error: 0.0153
# Epoch 14: val_loss did not improve from 0.00009
# 34/34 [==============================] - 1s 27ms/step - loss: 2.7212e-04 - mean_absolute_error: 0.0154 - val_loss: 1.1177e-04 - val_mean_absolute_error: 0.0130
# Epoch 15/30
# 34/34 [==============================] - ETA: 0s - loss: 2.8131e-04 - mean_absolute_error: 0.0155
# Epoch 15: val_loss did not improve from 0.00009
# 34/34 [==============================] - 1s 25ms/step - loss: 2.8131e-04 - mean_absolute_error: 0.0155 - val_loss: 3.6067e-04 - val_mean_absolute_error: 0.0254
# Epoch 16/30
# 34/34 [==============================] - ETA: 0s - loss: 3.1141e-04 - mean_absolute_error: 0.0162
# Epoch 16: val_loss did not improve from 0.00009
# 34/34 [==============================] - 1s 26ms/step - loss: 3.1141e-04 - mean_absolute_error: 0.0162 - val_loss: 3.2889e-04 - val_mean_absolute_error: 0.0245
# Epoch 17/30
# 32/34 [===========================>..] - ETA: 0s - loss: 2.6395e-04 - mean_absolute_error: 0.0153
# Epoch 17: val_loss did not improve from 0.00009
# 34/34 [==============================] - 1s 27ms/step - loss: 2.6069e-04 - mean_absolute_error: 0.0152 - val_loss: 1.1569e-04 - val_mean_absolute_error: 0.0127
# Epoch 18/30
# 34/34 [==============================] - ETA: 0s - loss: 2.9894e-04 - mean_absolute_error: 0.0161
# Epoch 18: val_loss did not improve from 0.00009
# 34/34 [==============================] - 1s 39ms/step - loss: 2.9894e-04 - mean_absolute_error: 0.0161 - val_loss: 1.8513e-04 - val_mean_absolute_error: 0.0178
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 0s 346ms/step
# [[0.7553393  0.75778633 0.76154417 0.7559837  0.75976455 0.7553087 ]]
# Epoch 1/30
# 34/34 [==============================] - ETA: 0s - loss: 0.0018 - mean_absolute_error: 0.0410
# Epoch 1: val_loss improved from inf to 0.00044, saving model to ./checkpoint/GRU/AdamW/50\005930_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 4s 61ms/step - loss: 0.0018 - mean_absolute_error: 0.0410 - val_loss: 4.3817e-04 - val_mean_absolute_error: 0.0241
# Epoch 2/30
# 34/34 [==============================] - ETA: 0s - loss: 4.7867e-04 - mean_absolute_error: 0.0202
# Epoch 2: val_loss improved from 0.00044 to 0.00014, saving model to ./checkpoint/GRU/AdamW/50\005930_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 1s 30ms/step - loss: 4.7867e-04 - mean_absolute_error: 0.0202 - val_loss: 1.3996e-04 - val_mean_absolute_error: 0.0142
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 3.5307e-04 - mean_absolute_error: 0.0172
# Epoch 3: val_loss did not improve from 0.00014
# 34/34 [==============================] - 1s 28ms/step - loss: 3.5307e-04 - mean_absolute_error: 0.0172 - val_loss: 2.9603e-04 - val_mean_absolute_error: 0.0223
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 2.8873e-04 - mean_absolute_error: 0.0157
# Epoch 4: val_loss improved from 0.00014 to 0.00005, saving model to ./checkpoint/GRU/AdamW/50\005930_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 2.8873e-04 - mean_absolute_error: 0.0157 - val_loss: 5.4434e-05 - val_mean_absolute_error: 0.0084
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 2.6153e-04 - mean_absolute_error: 0.0152
# Epoch 5: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 25ms/step - loss: 2.6153e-04 - mean_absolute_error: 0.0152 - val_loss: 3.3706e-04 - val_mean_absolute_error: 0.0243
# Epoch 6/30
# 34/34 [==============================] - ETA: 0s - loss: 2.5453e-04 - mean_absolute_error: 0.0151
# Epoch 6: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 26ms/step - loss: 2.5453e-04 - mean_absolute_error: 0.0151 - val_loss: 1.7734e-04 - val_mean_absolute_error: 0.0167
# Epoch 7/30
# 33/34 [============================>.] - ETA: 0s - loss: 2.2468e-04 - mean_absolute_error: 0.0147
# Epoch 7: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 34ms/step - loss: 2.2957e-04 - mean_absolute_error: 0.0148 - val_loss: 3.6276e-04 - val_mean_absolute_error: 0.0256
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 2.3385e-04 - mean_absolute_error: 0.0143
# Epoch 8: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 37ms/step - loss: 2.3385e-04 - mean_absolute_error: 0.0143 - val_loss: 3.7468e-04 - val_mean_absolute_error: 0.0250
# Epoch 9/30
# 33/34 [============================>.] - ETA: 0s - loss: 2.3163e-04 - mean_absolute_error: 0.0143
# Epoch 9: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 28ms/step - loss: 2.2888e-04 - mean_absolute_error: 0.0142 - val_loss: 2.4656e-04 - val_mean_absolute_error: 0.0198
# 1/1 [==============================] - 0s 468ms/step
# 1/1 [==============================] - 0s 352ms/step
# [[0.81157506 0.793206   0.8152632  0.8127841  0.8224218  0.81618357
#   0.8162532 ]]
# Epoch 1/30
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0017 - mean_absolute_error: 0.0408
# Epoch 1: val_loss improved from inf to 0.00123, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_S&P500_50.h5
# 34/34 [==============================] - 4s 44ms/step - loss: 0.0017 - mean_absolute_error: 0.0399 - val_loss: 0.0012 - val_mean_absolute_error: 0.0488
# Epoch 2/30
# 33/34 [============================>.] - ETA: 0s - loss: 5.4565e-04 - mean_absolute_error: 0.0226
# Epoch 2: val_loss improved from 0.00123 to 0.00081, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_S&P500_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 5.4112e-04 - mean_absolute_error: 0.0225 - val_loss: 8.1018e-04 - val_mean_absolute_error: 0.0395
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 3.3574e-04 - mean_absolute_error: 0.0173
# Epoch 3: val_loss improved from 0.00081 to 0.00013, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_S&P500_50.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 3.3574e-04 - mean_absolute_error: 0.0173 - val_loss: 1.3103e-04 - val_mean_absolute_error: 0.0134
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 2.9188e-04 - mean_absolute_error: 0.0163
# Epoch 4: val_loss did not improve from 0.00013
# 34/34 [==============================] - 1s 23ms/step - loss: 2.9188e-04 - mean_absolute_error: 0.0163 - val_loss: 4.7138e-04 - val_mean_absolute_error: 0.0296
# Epoch 5/30
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4619e-04 - mean_absolute_error: 0.0145
# Epoch 5: val_loss improved from 0.00013 to 0.00003, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_S&P500_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 2.4688e-04 - mean_absolute_error: 0.0146 - val_loss: 3.1474e-05 - val_mean_absolute_error: 0.0063
# Epoch 6/30
# 32/34 [===========================>..] - ETA: 0s - loss: 2.0109e-04 - mean_absolute_error: 0.0136
# Epoch 6: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 25ms/step - loss: 2.0465e-04 - mean_absolute_error: 0.0137 - val_loss: 1.1116e-04 - val_mean_absolute_error: 0.0129
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 2.1430e-04 - mean_absolute_error: 0.0138
# Epoch 7: val_loss improved from 0.00003 to 0.00003, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_S&P500_50.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 2.1430e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5323e-05 - val_mean_absolute_error: 0.0057
# Epoch 8/30
# 33/34 [============================>.] - ETA: 0s - loss: 2.1127e-04 - mean_absolute_error: 0.0142
# Epoch 8: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 24ms/step - loss: 2.1027e-04 - mean_absolute_error: 0.0141 - val_loss: 2.1581e-04 - val_mean_absolute_error: 0.0196
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 2.3145e-04 - mean_absolute_error: 0.0142
# Epoch 9: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 24ms/step - loss: 2.3145e-04 - mean_absolute_error: 0.0142 - val_loss: 3.4414e-05 - val_mean_absolute_error: 0.0067
# Epoch 10/30
# 34/34 [==============================] - ETA: 0s - loss: 2.0158e-04 - mean_absolute_error: 0.0134
# Epoch 10: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 23ms/step - loss: 2.0158e-04 - mean_absolute_error: 0.0134 - val_loss: 6.9920e-05 - val_mean_absolute_error: 0.0103
# Epoch 11/30
# 34/34 [==============================] - ETA: 0s - loss: 2.1872e-04 - mean_absolute_error: 0.0138
# Epoch 11: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 24ms/step - loss: 2.1872e-04 - mean_absolute_error: 0.0138 - val_loss: 1.6559e-04 - val_mean_absolute_error: 0.0157
# Epoch 12/30
# 32/34 [===========================>..] - ETA: 0s - loss: 2.1579e-04 - mean_absolute_error: 0.0138
# Epoch 12: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 25ms/step - loss: 2.1853e-04 - mean_absolute_error: 0.0139 - val_loss: 9.6826e-05 - val_mean_absolute_error: 0.0124
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 312ms/step
# [[0.8293654  0.8281286  0.83403265 0.8415012  0.83262926 0.8372782
#   0.83511174]]
# Epoch 1/30
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0507
# Epoch 1: val_loss improved from inf to 0.00059, saving model to ./checkpoint/GRU/AdamW/50\005930_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 3s 37ms/step - loss: 0.0026 - mean_absolute_error: 0.0496 - val_loss: 5.8740e-04 - val_mean_absolute_error: 0.0310
# Epoch 2/30
# 33/34 [============================>.] - ETA: 0s - loss: 5.7795e-04 - mean_absolute_error: 0.0233
# Epoch 2: val_loss improved from 0.00059 to 0.00014, saving model to ./checkpoint/GRU/AdamW/50\005930_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 5.7151e-04 - mean_absolute_error: 0.0231 - val_loss: 1.4049e-04 - val_mean_absolute_error: 0.0145
# Epoch 3/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.6224e-04 - mean_absolute_error: 0.0176
# Epoch 3: val_loss improved from 0.00014 to 0.00006, saving model to ./checkpoint/GRU/AdamW/50\005930_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 3.6060e-04 - mean_absolute_error: 0.0175 - val_loss: 5.5502e-05 - val_mean_absolute_error: 0.0086
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 2.9440e-04 - mean_absolute_error: 0.0166
# Epoch 4: val_loss did not improve from 0.00006
# 34/34 [==============================] - 1s 23ms/step - loss: 2.9440e-04 - mean_absolute_error: 0.0166 - val_loss: 5.3196e-04 - val_mean_absolute_error: 0.0320
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 3.0249e-04 - mean_absolute_error: 0.0166
# Epoch 5: val_loss did not improve from 0.00006
# 34/34 [==============================] - 1s 25ms/step - loss: 3.0249e-04 - mean_absolute_error: 0.0166 - val_loss: 3.7439e-04 - val_mean_absolute_error: 0.0265
# Epoch 6/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.0020e-04 - mean_absolute_error: 0.0161
# Epoch 6: val_loss improved from 0.00006 to 0.00005, saving model to ./checkpoint/GRU/AdamW/50\005930_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 3.0008e-04 - mean_absolute_error: 0.0161 - val_loss: 4.6265e-05 - val_mean_absolute_error: 0.0079
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 2.5296e-04 - mean_absolute_error: 0.0155
# Epoch 7: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 24ms/step - loss: 2.5296e-04 - mean_absolute_error: 0.0155 - val_loss: 3.2841e-04 - val_mean_absolute_error: 0.0242
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 2.4849e-04 - mean_absolute_error: 0.0147
# Epoch 8: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 23ms/step - loss: 2.4849e-04 - mean_absolute_error: 0.0147 - val_loss: 1.3403e-04 - val_mean_absolute_error: 0.0147
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 2.4887e-04 - mean_absolute_error: 0.0148
# Epoch 9: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 25ms/step - loss: 2.4887e-04 - mean_absolute_error: 0.0148 - val_loss: 7.3303e-05 - val_mean_absolute_error: 0.0100
# Epoch 10/30
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4127e-04 - mean_absolute_error: 0.0150
# Epoch 10: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 27ms/step - loss: 2.3951e-04 - mean_absolute_error: 0.0149 - val_loss: 3.8194e-04 - val_mean_absolute_error: 0.0265
# Epoch 11/30
# 34/34 [==============================] - ETA: 0s - loss: 2.5243e-04 - mean_absolute_error: 0.0147
# Epoch 11: val_loss did not improve from 0.00005
# 34/34 [==============================] - 1s 26ms/step - loss: 2.5243e-04 - mean_absolute_error: 0.0147 - val_loss: 2.0774e-04 - val_mean_absolute_error: 0.0193
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 372ms/step
# [[0.8491574  0.82137424 0.8152094  0.8319869  0.81944144 0.7836008
#   0.8099365 ]]
# Epoch 1/30
# 33/34 [============================>.] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0501
# Epoch 1: val_loss improved from inf to 0.00037, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_%K_50.h5
# 34/34 [==============================] - 3s 37ms/step - loss: 0.0025 - mean_absolute_error: 0.0495 - val_loss: 3.6859e-04 - val_mean_absolute_error: 0.0234
# Epoch 2/30
# 33/34 [============================>.] - ETA: 0s - loss: 5.6932e-04 - mean_absolute_error: 0.0217
# Epoch 2: val_loss improved from 0.00037 to 0.00025, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_%K_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 5.6716e-04 - mean_absolute_error: 0.0217 - val_loss: 2.4667e-04 - val_mean_absolute_error: 0.0164
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 4.1701e-04 - mean_absolute_error: 0.0182
# Epoch 3: val_loss improved from 0.00025 to 0.00013, saving model to ./checkpoint/GRU/AdamW/50\005930_ma10_%K_50.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 4.1701e-04 - mean_absolute_error: 0.0182 - val_loss: 1.2990e-04 - val_mean_absolute_error: 0.0123
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 4.0125e-04 - mean_absolute_error: 0.0182
# Epoch 4: val_loss did not improve from 0.00013
# 34/34 [==============================] - 1s 24ms/step - loss: 4.0125e-04 - mean_absolute_error: 0.0182 - val_loss: 3.5545e-04 - val_mean_absolute_error: 0.0248
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 3.6119e-04 - mean_absolute_error: 0.0172
# Epoch 5: val_loss did not improve from 0.00013
# 34/34 [==============================] - 1s 25ms/step - loss: 3.6119e-04 - mean_absolute_error: 0.0172 - val_loss: 3.4241e-04 - val_mean_absolute_error: 0.0244
# Epoch 6/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.6086e-04 - mean_absolute_error: 0.0174
# Epoch 6: val_loss did not improve from 0.00013
# 34/34 [==============================] - 1s 26ms/step - loss: 3.5832e-04 - mean_absolute_error: 0.0173 - val_loss: 2.9284e-04 - val_mean_absolute_error: 0.0231
# Epoch 7/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.7926e-04 - mean_absolute_error: 0.0184
# Epoch 7: val_loss did not improve from 0.00013
# 34/34 [==============================] - 1s 26ms/step - loss: 3.8027e-04 - mean_absolute_error: 0.0184 - val_loss: 2.9292e-04 - val_mean_absolute_error: 0.0234
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 3.4064e-04 - mean_absolute_error: 0.0166
# Epoch 8: val_loss did not improve from 0.00013
# 34/34 [==============================] - 1s 25ms/step - loss: 3.4064e-04 - mean_absolute_error: 0.0166 - val_loss: 2.5809e-04 - val_mean_absolute_error: 0.0213
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 337ms/step
# [[0.7067312  0.73126245 0.7206875  0.66488886 0.7010323  0.7001701
#   0.72705156]]
# Epoch 1/30
# 34/34 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0448
# Epoch 1: val_loss improved from inf to 0.00076, saving model to ./checkpoint/GRU/AdamW/50\005930_ma20_S&P500_50.h5
# 34/34 [==============================] - 3s 37ms/step - loss: 0.0022 - mean_absolute_error: 0.0448 - val_loss: 7.6338e-04 - val_mean_absolute_error: 0.0358
# Epoch 2/30
# 33/34 [============================>.] - ETA: 0s - loss: 5.2335e-04 - mean_absolute_error: 0.0198
# Epoch 2: val_loss improved from 0.00076 to 0.00043, saving model to ./checkpoint/GRU/AdamW/50\005930_ma20_S&P500_50.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 5.2424e-04 - mean_absolute_error: 0.0198 - val_loss: 4.2885e-04 - val_mean_absolute_error: 0.0261
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 4.1467e-04 - mean_absolute_error: 0.0188
# Epoch 3: val_loss improved from 0.00043 to 0.00015, saving model to ./checkpoint/GRU/AdamW/50\005930_ma20_S&P500_50.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 4.1467e-04 - mean_absolute_error: 0.0188 - val_loss: 1.4517e-04 - val_mean_absolute_error: 0.0142
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 3.7405e-04 - mean_absolute_error: 0.0175
# Epoch 4: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 24ms/step - loss: 3.7405e-04 - mean_absolute_error: 0.0175 - val_loss: 6.6542e-04 - val_mean_absolute_error: 0.0344
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 3.6547e-04 - mean_absolute_error: 0.0173
# Epoch 5: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 28ms/step - loss: 3.6547e-04 - mean_absolute_error: 0.0173 - val_loss: 6.2662e-04 - val_mean_absolute_error: 0.0334
# Epoch 6/30
# 32/34 [===========================>..] - ETA: 0s - loss: 3.3761e-04 - mean_absolute_error: 0.0167
# Epoch 6: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 26ms/step - loss: 3.3541e-04 - mean_absolute_error: 0.0167 - val_loss: 4.1013e-04 - val_mean_absolute_error: 0.0266
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 3.4948e-04 - mean_absolute_error: 0.0170
# Epoch 7: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 25ms/step - loss: 3.4948e-04 - mean_absolute_error: 0.0170 - val_loss: 2.4837e-04 - val_mean_absolute_error: 0.0204
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 3.7075e-04 - mean_absolute_error: 0.0173
# Epoch 8: val_loss improved from 0.00015 to 0.00006, saving model to ./checkpoint/GRU/AdamW/50\005930_ma20_S&P500_50.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 3.7075e-04 - mean_absolute_error: 0.0173 - val_loss: 6.2513e-05 - val_mean_absolute_error: 0.0092
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 3.7590e-04 - mean_absolute_error: 0.0174
# Epoch 9: val_loss did not improve from 0.00006
# 34/34 [==============================] - 1s 25ms/step - loss: 3.7590e-04 - mean_absolute_error: 0.0174 - val_loss: 3.9871e-04 - val_mean_absolute_error: 0.0262
# Epoch 10/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.8264e-04 - mean_absolute_error: 0.0180
# Epoch 10: val_loss did not improve from 0.00006
# 34/34 [==============================] - 1s 25ms/step - loss: 3.7961e-04 - mean_absolute_error: 0.0179 - val_loss: 1.6757e-04 - val_mean_absolute_error: 0.0156
# Epoch 11/30
# 34/34 [==============================] - ETA: 0s - loss: 3.4955e-04 - mean_absolute_error: 0.0174
# Epoch 11: val_loss did not improve from 0.00006
# 34/34 [==============================] - 1s 25ms/step - loss: 3.4955e-04 - mean_absolute_error: 0.0174 - val_loss: 2.6329e-04 - val_mean_absolute_error: 0.0214
# Epoch 12/30
# 33/34 [============================>.] - ETA: 0s - loss: 3.5299e-04 - mean_absolute_error: 0.0169
# Epoch 12: val_loss did not improve from 0.00006
# 34/34 [==============================] - 1s 28ms/step - loss: 3.5819e-04 - mean_absolute_error: 0.0170 - val_loss: 7.0645e-04 - val_mean_absolute_error: 0.0344
# Epoch 13/30
# 34/34 [==============================] - ETA: 0s - loss: 3.5026e-04 - mean_absolute_error: 0.0176
# Epoch 13: val_loss did not improve from 0.00006
# 34/34 [==============================] - 1s 23ms/step - loss: 3.5026e-04 - mean_absolute_error: 0.0176 - val_loss: 8.2215e-05 - val_mean_absolute_error: 0.0104
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 302ms/step
# [[0.80593395 0.7548223  0.7710971  0.7845164  0.7710721  0.8166734
#   0.81747353]]
# Epoch 1/30
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0018 - mean_absolute_error: 0.0399
# Epoch 1: val_loss improved from inf to 0.00032, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_bb_upper_50.h5
# 34/34 [==============================] - 3s 36ms/step - loss: 0.0017 - mean_absolute_error: 0.0389 - val_loss: 3.1764e-04 - val_mean_absolute_error: 0.0210
# Epoch 2/30
# 34/34 [==============================] - ETA: 0s - loss: 4.2220e-04 - mean_absolute_error: 0.0198
# Epoch 2: val_loss improved from 0.00032 to 0.00017, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_bb_upper_50.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 4.2220e-04 - mean_absolute_error: 0.0198 - val_loss: 1.6984e-04 - val_mean_absolute_error: 0.0158
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 3.2077e-04 - mean_absolute_error: 0.0170
# Epoch 3: val_loss improved from 0.00017 to 0.00011, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_bb_upper_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 3.2077e-04 - mean_absolute_error: 0.0170 - val_loss: 1.0612e-04 - val_mean_absolute_error: 0.0119
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 2.8913e-04 - mean_absolute_error: 0.0166
# Epoch 4: val_loss did not improve from 0.00011
# 34/34 [==============================] - 1s 25ms/step - loss: 2.8913e-04 - mean_absolute_error: 0.0166 - val_loss: 2.0020e-04 - val_mean_absolute_error: 0.0176
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 2.9214e-04 - mean_absolute_error: 0.0167
# Epoch 5: val_loss improved from 0.00011 to 0.00004, saving model to ./checkpoint/GRU/AdamW/50\005930_Kospi_bb_upper_50.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 2.9214e-04 - mean_absolute_error: 0.0167 - val_loss: 4.0829e-05 - val_mean_absolute_error: 0.0073
# Epoch 6/30
# 34/34 [==============================] - ETA: 0s - loss: 2.3097e-04 - mean_absolute_error: 0.0146
# Epoch 6: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 23ms/step - loss: 2.3097e-04 - mean_absolute_error: 0.0146 - val_loss: 1.4336e-04 - val_mean_absolute_error: 0.0152
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 2.3382e-04 - mean_absolute_error: 0.0142
# Epoch 7: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 25ms/step - loss: 2.3382e-04 - mean_absolute_error: 0.0142 - val_loss: 1.0332e-04 - val_mean_absolute_error: 0.0127
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 2.2363e-04 - mean_absolute_error: 0.0140
# Epoch 8: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 23ms/step - loss: 2.2363e-04 - mean_absolute_error: 0.0140 - val_loss: 6.1451e-05 - val_mean_absolute_error: 0.0093
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 2.2885e-04 - mean_absolute_error: 0.0148
# Epoch 9: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 24ms/step - loss: 2.2885e-04 - mean_absolute_error: 0.0148 - val_loss: 7.8899e-05 - val_mean_absolute_error: 0.0106
# Epoch 10/30
# 34/34 [==============================] - ETA: 0s - loss: 2.0068e-04 - mean_absolute_error: 0.0135
# Epoch 10: val_loss did not improve from 0.00004
# 34/34 [==============================] - 1s 24ms/step - loss: 2.0068e-04 - mean_absolute_error: 0.0135 - val_loss: 1.3916e-04 - val_mean_absolute_error: 0.0151
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 311ms/step
# [[0.71539074 0.7697388  0.7280426  0.7694491  0.7508951  0.7205919
#   0.75811726]]
# Epoch 1/30
# 33/34 [============================>.] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0417
# Epoch 1: val_loss improved from inf to 0.00033, saving model to ./checkpoint/GRU/AdamW/50\000660_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 3s 36ms/step - loss: 0.0040 - mean_absolute_error: 0.0414 - val_loss: 3.3348e-04 - val_mean_absolute_error: 0.0239
# Epoch 2/30
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0222
# Epoch 2: val_loss did not improve from 0.00033
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0012 - mean_absolute_error: 0.0222 - val_loss: 3.6844e-04 - val_mean_absolute_error: 0.0256
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 9.1187e-04 - mean_absolute_error: 0.0199
# Epoch 3: val_loss did not improve from 0.00033
# 34/34 [==============================] - 1s 24ms/step - loss: 9.1187e-04 - mean_absolute_error: 0.0199 - val_loss: 4.4616e-04 - val_mean_absolute_error: 0.0286
# Epoch 4/30
# 33/34 [============================>.] - ETA: 0s - loss: 9.7756e-04 - mean_absolute_error: 0.0204
# Epoch 4: val_loss did not improve from 0.00033
# 34/34 [==============================] - 1s 26ms/step - loss: 9.7484e-04 - mean_absolute_error: 0.0204 - val_loss: 4.8420e-04 - val_mean_absolute_error: 0.0300
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 9.4476e-04 - mean_absolute_error: 0.0205
# Epoch 5: val_loss improved from 0.00033 to 0.00030, saving model to ./checkpoint/GRU/AdamW/50\000660_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 9.4476e-04 - mean_absolute_error: 0.0205 - val_loss: 2.9973e-04 - val_mean_absolute_error: 0.0228
# Epoch 6/30
# 34/34 [==============================] - ETA: 0s - loss: 8.3044e-04 - mean_absolute_error: 0.0206
# Epoch 6: val_loss did not improve from 0.00030
# 34/34 [==============================] - 1s 24ms/step - loss: 8.3044e-04 - mean_absolute_error: 0.0206 - val_loss: 3.6811e-04 - val_mean_absolute_error: 0.0263
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 8.5796e-04 - mean_absolute_error: 0.0201
# Epoch 7: val_loss did not improve from 0.00030
# 34/34 [==============================] - 1s 25ms/step - loss: 8.5796e-04 - mean_absolute_error: 0.0201 - val_loss: 3.5929e-04 - val_mean_absolute_error: 0.0253
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 7.0445e-04 - mean_absolute_error: 0.0175
# Epoch 8: val_loss improved from 0.00030 to 0.00018, saving model to ./checkpoint/GRU/AdamW/50\000660_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 7.0445e-04 - mean_absolute_error: 0.0175 - val_loss: 1.8336e-04 - val_mean_absolute_error: 0.0179
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 5.8047e-04 - mean_absolute_error: 0.0157
# Epoch 9: val_loss did not improve from 0.00018
# 34/34 [==============================] - 1s 23ms/step - loss: 5.8047e-04 - mean_absolute_error: 0.0157 - val_loss: 3.6564e-04 - val_mean_absolute_error: 0.0260
# Epoch 10/30
# 34/34 [==============================] - ETA: 0s - loss: 6.9723e-04 - mean_absolute_error: 0.0177
# Epoch 10: val_loss did not improve from 0.00018
# 34/34 [==============================] - 1s 24ms/step - loss: 6.9723e-04 - mean_absolute_error: 0.0177 - val_loss: 3.7239e-04 - val_mean_absolute_error: 0.0265
# Epoch 11/30
# 32/34 [===========================>..] - ETA: 0s - loss: 6.8720e-04 - mean_absolute_error: 0.0175
# Epoch 11: val_loss did not improve from 0.00018
# 34/34 [==============================] - 1s 26ms/step - loss: 6.8104e-04 - mean_absolute_error: 0.0174 - val_loss: 2.2442e-04 - val_mean_absolute_error: 0.0196
# Epoch 12/30
# 33/34 [============================>.] - ETA: 0s - loss: 7.8797e-04 - mean_absolute_error: 0.0185
# Epoch 12: val_loss did not improve from 0.00018
# 34/34 [==============================] - 1s 24ms/step - loss: 7.7606e-04 - mean_absolute_error: 0.0184 - val_loss: 3.2244e-04 - val_mean_absolute_error: 0.0237
# Epoch 13/30
# 34/34 [==============================] - ETA: 0s - loss: 7.0528e-04 - mean_absolute_error: 0.0165
# Epoch 13: val_loss improved from 0.00018 to 0.00017, saving model to ./checkpoint/GRU/AdamW/50\000660_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 7.0528e-04 - mean_absolute_error: 0.0165 - val_loss: 1.6512e-04 - val_mean_absolute_error: 0.0162
# Epoch 14/30
# 33/34 [============================>.] - ETA: 0s - loss: 5.8239e-04 - mean_absolute_error: 0.0156
# Epoch 14: val_loss did not improve from 0.00017
# 34/34 [==============================] - 1s 24ms/step - loss: 5.8000e-04 - mean_absolute_error: 0.0156 - val_loss: 2.5685e-04 - val_mean_absolute_error: 0.0209
# Epoch 15/30
# 34/34 [==============================] - ETA: 0s - loss: 6.9009e-04 - mean_absolute_error: 0.0159
# Epoch 15: val_loss did not improve from 0.00017
# 34/34 [==============================] - 1s 23ms/step - loss: 6.9009e-04 - mean_absolute_error: 0.0159 - val_loss: 2.6646e-04 - val_mean_absolute_error: 0.0212
# Epoch 16/30
# 33/34 [============================>.] - ETA: 0s - loss: 6.6397e-04 - mean_absolute_error: 0.0162
# Epoch 16: val_loss did not improve from 0.00017
# 34/34 [==============================] - 1s 26ms/step - loss: 6.6106e-04 - mean_absolute_error: 0.0162 - val_loss: 1.9941e-04 - val_mean_absolute_error: 0.0182
# Epoch 17/30
# 34/34 [==============================] - ETA: 0s - loss: 6.1450e-04 - mean_absolute_error: 0.0152
# Epoch 17: val_loss did not improve from 0.00017
# 34/34 [==============================] - 1s 26ms/step - loss: 6.1450e-04 - mean_absolute_error: 0.0152 - val_loss: 2.0576e-04 - val_mean_absolute_error: 0.0188
# Epoch 18/30
# 33/34 [============================>.] - ETA: 0s - loss: 6.3940e-04 - mean_absolute_error: 0.0172
# Epoch 18: val_loss improved from 0.00017 to 0.00015, saving model to ./checkpoint/GRU/AdamW/50\000660_Kospi_S&P500_bb_upper_50.h5
# 34/34 [==============================] - 1s 29ms/step - loss: 6.3567e-04 - mean_absolute_error: 0.0172 - val_loss: 1.4957e-04 - val_mean_absolute_error: 0.0156
# Epoch 19/30
# 32/34 [===========================>..] - ETA: 0s - loss: 7.0769e-04 - mean_absolute_error: 0.0179
# Epoch 19: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 26ms/step - loss: 7.1753e-04 - mean_absolute_error: 0.0182 - val_loss: 6.0733e-04 - val_mean_absolute_error: 0.0341
# Epoch 20/30
# 33/34 [============================>.] - ETA: 0s - loss: 6.6263e-04 - mean_absolute_error: 0.0173
# Epoch 20: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 25ms/step - loss: 6.6039e-04 - mean_absolute_error: 0.0173 - val_loss: 1.6583e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/30
# 33/34 [============================>.] - ETA: 0s - loss: 7.0613e-04 - mean_absolute_error: 0.0167
# Epoch 21: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 24ms/step - loss: 7.0608e-04 - mean_absolute_error: 0.0168 - val_loss: 1.5050e-04 - val_mean_absolute_error: 0.0155
# Epoch 22/30
# 34/34 [==============================] - ETA: 0s - loss: 6.5500e-04 - mean_absolute_error: 0.0156
# Epoch 22: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 23ms/step - loss: 6.5500e-04 - mean_absolute_error: 0.0156 - val_loss: 1.9642e-04 - val_mean_absolute_error: 0.0183
# Epoch 23/30
# 34/34 [==============================] - ETA: 0s - loss: 6.4858e-04 - mean_absolute_error: 0.0157
# Epoch 23: val_loss did not improve from 0.00015
# 34/34 [==============================] - 1s 23ms/step - loss: 6.4858e-04 - mean_absolute_error: 0.0157 - val_loss: 2.6512e-04 - val_mean_absolute_error: 0.0216
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 312ms/step
# [[0.83694035 0.84001786 0.8389651  0.8391639  0.8383364  0.840038
#   0.83770525 0.8400547 ]]
# Epoch 1/30
# 34/34 [==============================] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0395
# Epoch 1: val_loss improved from inf to 0.00007, saving model to ./checkpoint/GRU/AdamW/50\000660_ma10_50.h5
# 34/34 [==============================] - 3s 38ms/step - loss: 0.0040 - mean_absolute_error: 0.0395 - val_loss: 7.3742e-05 - val_mean_absolute_error: 0.0109
# Epoch 2/30
# 33/34 [============================>.] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0242
# Epoch 2: val_loss improved from 0.00007 to 0.00001, saving model to ./checkpoint/GRU/AdamW/50\000660_ma10_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0012 - mean_absolute_error: 0.0241 - val_loss: 1.1318e-05 - val_mean_absolute_error: 0.0040
# Epoch 3/30
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0208
# Epoch 3: val_loss did not improve from 0.00001
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0010 - mean_absolute_error: 0.0207 - val_loss: 8.3215e-05 - val_mean_absolute_error: 0.0121
# Epoch 4/30
# 32/34 [===========================>..] - ETA: 0s - loss: 7.6010e-04 - mean_absolute_error: 0.0180
# Epoch 4: val_loss did not improve from 0.00001
# 34/34 [==============================] - 1s 26ms/step - loss: 7.8191e-04 - mean_absolute_error: 0.0180 - val_loss: 1.2804e-04 - val_mean_absolute_error: 0.0151
# Epoch 5/30
# 33/34 [============================>.] - ETA: 0s - loss: 8.9190e-04 - mean_absolute_error: 0.0197
# Epoch 5: val_loss did not improve from 0.00001
# 34/34 [==============================] - 1s 25ms/step - loss: 8.8316e-04 - mean_absolute_error: 0.0197 - val_loss: 5.4099e-05 - val_mean_absolute_error: 0.0097
# Epoch 6/30
# 33/34 [============================>.] - ETA: 0s - loss: 8.4886e-04 - mean_absolute_error: 0.0192
# Epoch 6: val_loss did not improve from 0.00001
# 34/34 [==============================] - 1s 24ms/step - loss: 8.4357e-04 - mean_absolute_error: 0.0192 - val_loss: 6.0890e-05 - val_mean_absolute_error: 0.0102
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 8.0631e-04 - mean_absolute_error: 0.0190
# Epoch 7: val_loss did not improve from 0.00001
# 34/34 [==============================] - 1s 23ms/step - loss: 8.0631e-04 - mean_absolute_error: 0.0190 - val_loss: 4.6221e-05 - val_mean_absolute_error: 0.0086
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 314ms/step
# [[0.975121   0.93524015 1.0173544  0.9683379  0.9917958  0.9954091 ]]
# Epoch 1/30
# 34/34 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0414
# Epoch 1: val_loss improved from inf to 0.00030, saving model to ./checkpoint/GRU/AdamW/50\000660_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 3s 40ms/step - loss: 0.0038 - mean_absolute_error: 0.0414 - val_loss: 2.9564e-04 - val_mean_absolute_error: 0.0234
# Epoch 2/30
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013 - mean_absolute_error: 0.0244
# Epoch 2: val_loss improved from 0.00030 to 0.00019, saving model to ./checkpoint/GRU/AdamW/50\000660_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0013 - mean_absolute_error: 0.0244 - val_loss: 1.9463e-04 - val_mean_absolute_error: 0.0192
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 9.9627e-04 - mean_absolute_error: 0.0225
# Epoch 3: val_loss did not improve from 0.00019
# 34/34 [==============================] - 1s 23ms/step - loss: 9.9627e-04 - mean_absolute_error: 0.0225 - val_loss: 2.2968e-04 - val_mean_absolute_error: 0.0210
# Epoch 4/30
# 32/34 [===========================>..] - ETA: 0s - loss: 8.7795e-04 - mean_absolute_error: 0.0209
# Epoch 4: val_loss did not improve from 0.00019
# 34/34 [==============================] - 1s 26ms/step - loss: 8.7829e-04 - mean_absolute_error: 0.0210 - val_loss: 4.4360e-04 - val_mean_absolute_error: 0.0297
# Epoch 5/30
# 34/34 [==============================] - ETA: 0s - loss: 8.4893e-04 - mean_absolute_error: 0.0210
# Epoch 5: val_loss improved from 0.00019 to 0.00003, saving model to ./checkpoint/GRU/AdamW/50\000660_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 1s 32ms/step - loss: 8.4893e-04 - mean_absolute_error: 0.0210 - val_loss: 3.0357e-05 - val_mean_absolute_error: 0.0070
# Epoch 6/30
# 34/34 [==============================] - ETA: 0s - loss: 6.6003e-04 - mean_absolute_error: 0.0183
# Epoch 6: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 25ms/step - loss: 6.6003e-04 - mean_absolute_error: 0.0183 - val_loss: 2.7348e-04 - val_mean_absolute_error: 0.0231
# Epoch 7/30
# 34/34 [==============================] - ETA: 0s - loss: 7.4777e-04 - mean_absolute_error: 0.0192
# Epoch 7: val_loss did not improve from 0.00003
# 34/34 [==============================] - 1s 25ms/step - loss: 7.4777e-04 - mean_absolute_error: 0.0192 - val_loss: 2.5979e-04 - val_mean_absolute_error: 0.0222
# Epoch 8/30
# 34/34 [==============================] - ETA: 0s - loss: 5.8669e-04 - mean_absolute_error: 0.0173
# Epoch 8: val_loss improved from 0.00003 to 0.00002, saving model to ./checkpoint/GRU/AdamW/50\000660_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 5.8669e-04 - mean_absolute_error: 0.0173 - val_loss: 2.3789e-05 - val_mean_absolute_error: 0.0064
# Epoch 9/30
# 34/34 [==============================] - ETA: 0s - loss: 7.0704e-04 - mean_absolute_error: 0.0169
# Epoch 9: val_loss improved from 0.00002 to 0.00000, saving model to ./checkpoint/GRU/AdamW/50\000660_high_low_diff_bb_upper_50.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 7.0704e-04 - mean_absolute_error: 0.0169 - val_loss: 4.7959e-06 - val_mean_absolute_error: 0.0026
# Epoch 10/30
# 33/34 [============================>.] - ETA: 0s - loss: 6.8828e-04 - mean_absolute_error: 0.0184
# Epoch 10: val_loss did not improve from 0.00000
# 34/34 [==============================] - 1s 25ms/step - loss: 6.7776e-04 - mean_absolute_error: 0.0182 - val_loss: 5.1984e-05 - val_mean_absolute_error: 0.0098
# Epoch 11/30
# 32/34 [===========================>..] - ETA: 0s - loss: 6.6686e-04 - mean_absolute_error: 0.0159
# Epoch 11: val_loss did not improve from 0.00000
# 34/34 [==============================] - 1s 27ms/step - loss: 6.7052e-04 - mean_absolute_error: 0.0160 - val_loss: 1.8821e-05 - val_mean_absolute_error: 0.0054
# Epoch 12/30
# 34/34 [==============================] - ETA: 0s - loss: 7.3188e-04 - mean_absolute_error: 0.0178
# ...
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0130 - mean_absolute_error: 0.1175
# Epoch 12: val_loss did not improve from 0.00445
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0128 - mean_absolute_error: 0.1142 - val_loss: 0.0056 - val_mean_absolute_error: 0.0873
# Epoch 13/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0114 - mean_absolute_error: 0.1056
# Epoch 13: val_loss did not improve from 0.00445
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0100 - mean_absolute_error: 0.0937 - val_loss: 0.0068 - val_mean_absolute_error: 0.1001
# Epoch 14/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0872
# Epoch 14: val_loss did not improve from 0.00445
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0083 - mean_absolute_error: 0.0945 - val_loss: 0.0063 - val_mean_absolute_error: 0.0952
# Epoch 15/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0097 - mean_absolute_error: 0.1019
# Epoch 15: val_loss improved from 0.00445 to 0.00428, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0097 - mean_absolute_error: 0.1040 - val_loss: 0.0043 - val_mean_absolute_error: 0.0733
# Epoch 16/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0082 - mean_absolute_error: 0.0920
# Epoch 16: val_loss improved from 0.00428 to 0.00277, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0078 - mean_absolute_error: 0.0851 - val_loss: 0.0028 - val_mean_absolute_error: 0.0557
# Epoch 17/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0102 - mean_absolute_error: 0.1023
# Epoch 17: val_loss improved from 0.00277 to 0.00253, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0087 - mean_absolute_error: 0.0909 - val_loss: 0.0025 - val_mean_absolute_error: 0.0529
# Epoch 18/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0079 - mean_absolute_error: 0.0911
# Epoch 18: val_loss did not improve from 0.00253
# 2/2 [==============================] - 0s 130ms/step - loss: 0.0075 - mean_absolute_error: 0.0895 - val_loss: 0.0032 - val_mean_absolute_error: 0.0612
# Epoch 19/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0890
# Epoch 19: val_loss did not improve from 0.00253
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0070 - mean_absolute_error: 0.0877 - val_loss: 0.0036 - val_mean_absolute_error: 0.0658
# Epoch 20/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0756
# Epoch 20: val_loss did not improve from 0.00253
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0051 - mean_absolute_error: 0.0703 - val_loss: 0.0028 - val_mean_absolute_error: 0.0557
# Epoch 21/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0731
# Epoch 21: val_loss improved from 0.00253 to 0.00249, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0051 - mean_absolute_error: 0.0709 - val_loss: 0.0025 - val_mean_absolute_error: 0.0523
# Epoch 22/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0662
# Epoch 22: val_loss did not improve from 0.00249
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0046 - mean_absolute_error: 0.0737 - val_loss: 0.0027 - val_mean_absolute_error: 0.0553
# Epoch 23/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0045 - mean_absolute_error: 0.0677
# Epoch 23: val_loss did not improve from 0.00249
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0045 - mean_absolute_error: 0.0634 - val_loss: 0.0028 - val_mean_absolute_error: 0.0572
# Epoch 24/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0049 - mean_absolute_error: 0.0707
# Epoch 24: val_loss improved from 0.00249 to 0.00227, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0058 - mean_absolute_error: 0.0820 - val_loss: 0.0023 - val_mean_absolute_error: 0.0509
# Epoch 25/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0058 - mean_absolute_error: 0.0705
# Epoch 25: val_loss improved from 0.00227 to 0.00178, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0053 - mean_absolute_error: 0.0681 - val_loss: 0.0018 - val_mean_absolute_error: 0.0449
# Epoch 26/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0039 - mean_absolute_error: 0.0675
# Epoch 26: val_loss did not improve from 0.00178
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0038 - mean_absolute_error: 0.0649 - val_loss: 0.0018 - val_mean_absolute_error: 0.0452
# Epoch 27/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0624
# Epoch 27: val_loss did not improve from 0.00178
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0047 - mean_absolute_error: 0.0695 - val_loss: 0.0019 - val_mean_absolute_error: 0.0463
# Epoch 28/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0713
# Epoch 28: val_loss improved from 0.00178 to 0.00166, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0049 - mean_absolute_error: 0.0671 - val_loss: 0.0017 - val_mean_absolute_error: 0.0440
# Epoch 29/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0554
# Epoch 29: val_loss improved from 0.00166 to 0.00159, saving model to ./checkpoint/GRU/AdamW/50\352820_ma20_S&P500_50.h5
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0037 - mean_absolute_error: 0.0667 - val_loss: 0.0016 - val_mean_absolute_error: 0.0430
# Epoch 30/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0586
# Epoch 30: val_loss did not improve from 0.00159
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0034 - mean_absolute_error: 0.0609 - val_loss: 0.0019 - val_mean_absolute_error: 0.0459
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 324ms/step
# [[0.5195812  0.5028588  0.5328392  0.5078724  0.5140055  0.5024322
#   0.52510023]]
# Epoch 1/30
# 1/2 [==============>...............] - ETA: 1s - loss: 0.1533 - mean_absolute_error: 0.4739
# Epoch 1: val_loss improved from inf to 0.06777, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 2s 529ms/step - loss: 0.1276 - mean_absolute_error: 0.3925 - val_loss: 0.0678 - val_mean_absolute_error: 0.3369
# Epoch 2/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0527 - mean_absolute_error: 0.2599
# Epoch 2: val_loss improved from 0.06777 to 0.03533, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0498 - mean_absolute_error: 0.2447 - val_loss: 0.0353 - val_mean_absolute_error: 0.2165
# Epoch 3/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0383 - mean_absolute_error: 0.2195
# Epoch 3: val_loss improved from 0.03533 to 0.02654, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0366 - mean_absolute_error: 0.2114 - val_loss: 0.0265 - val_mean_absolute_error: 0.1847
# Epoch 4/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0318 - mean_absolute_error: 0.1946
# Epoch 4: val_loss improved from 0.02654 to 0.01967, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0301 - mean_absolute_error: 0.1868 - val_loss: 0.0197 - val_mean_absolute_error: 0.1650
# Epoch 5/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0220 - mean_absolute_error: 0.1615
# Epoch 5: val_loss improved from 0.01967 to 0.01248, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0200 - mean_absolute_error: 0.1502 - val_loss: 0.0125 - val_mean_absolute_error: 0.1309
# Epoch 6/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0157 - mean_absolute_error: 0.1390
# Epoch 6: val_loss improved from 0.01248 to 0.01247, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0153 - mean_absolute_error: 0.1350 - val_loss: 0.0125 - val_mean_absolute_error: 0.1285
# Epoch 7/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0161 - mean_absolute_error: 0.1397
# Epoch 7: val_loss did not improve from 0.01247
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0159 - mean_absolute_error: 0.1372 - val_loss: 0.0141 - val_mean_absolute_error: 0.1419
# Epoch 8/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0148 - mean_absolute_error: 0.1341
# Epoch 8: val_loss improved from 0.01247 to 0.00863, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0138 - mean_absolute_error: 0.1256 - val_loss: 0.0086 - val_mean_absolute_error: 0.1049
# Epoch 9/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0090 - mean_absolute_error: 0.1053
# Epoch 9: val_loss improved from 0.00863 to 0.00503, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0106 - mean_absolute_error: 0.1189 - val_loss: 0.0050 - val_mean_absolute_error: 0.0807
# Epoch 10/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.1180
# Epoch 10: val_loss improved from 0.00503 to 0.00353, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0117 - mean_absolute_error: 0.1164 - val_loss: 0.0035 - val_mean_absolute_error: 0.0662
# Epoch 11/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0083 - mean_absolute_error: 0.1023
# Epoch 11: val_loss did not improve from 0.00353
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0080 - mean_absolute_error: 0.1000 - val_loss: 0.0041 - val_mean_absolute_error: 0.0748
# Epoch 12/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0086 - mean_absolute_error: 0.1017
# Epoch 12: val_loss improved from 0.00353 to 0.00298, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0079 - mean_absolute_error: 0.0940 - val_loss: 0.0030 - val_mean_absolute_error: 0.0626
# Epoch 13/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0081 - mean_absolute_error: 0.0985
# Epoch 13: val_loss improved from 0.00298 to 0.00189, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0081 - mean_absolute_error: 0.0982 - val_loss: 0.0019 - val_mean_absolute_error: 0.0484
# Epoch 14/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0080 - mean_absolute_error: 0.0995
# Epoch 14: val_loss did not improve from 0.00189
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0075 - mean_absolute_error: 0.0933 - val_loss: 0.0023 - val_mean_absolute_error: 0.0550
# Epoch 15/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0071 - mean_absolute_error: 0.0950
# Epoch 15: val_loss did not improve from 0.00189
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0068 - mean_absolute_error: 0.0901 - val_loss: 0.0023 - val_mean_absolute_error: 0.0541
# Epoch 16/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0779
# Epoch 16: val_loss did not improve from 0.00189
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0052 - mean_absolute_error: 0.0787 - val_loss: 0.0025 - val_mean_absolute_error: 0.0570
# Epoch 17/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0061 - mean_absolute_error: 0.0815
# Epoch 17: val_loss improved from 0.00189 to 0.00173, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0062 - mean_absolute_error: 0.0824 - val_loss: 0.0017 - val_mean_absolute_error: 0.0458
# Epoch 18/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0063 - mean_absolute_error: 0.0846
# Epoch 18: val_loss improved from 0.00173 to 0.00134, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0061 - mean_absolute_error: 0.0823 - val_loss: 0.0013 - val_mean_absolute_error: 0.0400
# Epoch 19/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0808
# Epoch 19: val_loss improved from 0.00134 to 0.00116, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0057 - mean_absolute_error: 0.0833 - val_loss: 0.0012 - val_mean_absolute_error: 0.0371
# Epoch 20/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0770
# Epoch 20: val_loss did not improve from 0.00116
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0045 - mean_absolute_error: 0.0675 - val_loss: 0.0021 - val_mean_absolute_error: 0.0530
# Epoch 21/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0612
# Epoch 21: val_loss did not improve from 0.00116
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0038 - mean_absolute_error: 0.0695 - val_loss: 0.0041 - val_mean_absolute_error: 0.0817
# Epoch 22/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0788
# Epoch 22: val_loss improved from 0.00116 to 0.00082, saving model to ./checkpoint/GRU/AdamW/50\352820_Kospi_bb_upper_50.h5
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0053 - mean_absolute_error: 0.0746 - val_loss: 8.1665e-04 - val_mean_absolute_error: 0.0315
# Epoch 23/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0801
# Epoch 23: val_loss did not improve from 0.00082
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0049 - mean_absolute_error: 0.0765 - val_loss: 8.8031e-04 - val_mean_absolute_error: 0.0323
# Epoch 24/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0635
# Epoch 24: val_loss did not improve from 0.00082
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0032 - mean_absolute_error: 0.0620 - val_loss: 0.0023 - val_mean_absolute_error: 0.0565
# Epoch 25/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0589
# Epoch 25: val_loss did not improve from 0.00082
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0033 - mean_absolute_error: 0.0623 - val_loss: 0.0017 - val_mean_absolute_error: 0.0467
# Epoch 26/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0638
# Epoch 26: val_loss did not improve from 0.00082
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0032 - mean_absolute_error: 0.0603 - val_loss: 9.4956e-04 - val_mean_absolute_error: 0.0336
# Epoch 27/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0700
# Epoch 27: val_loss did not improve from 0.00082
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0038 - mean_absolute_error: 0.0625 - val_loss: 0.0016 - val_mean_absolute_error: 0.0442
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 362ms/step
# [[0.42323747 0.37596726 0.44391376 0.36487836 0.39295456 0.4070838
#   0.39604774]]

# %%
# print(stock_num)
import pandas as pd


# 데이터를 DataFrame으로 변환
df = pd.DataFrame(result_pridict)

# DataFrame을 엑셀 파일로 저장
df.to_excel('GRU_adamW_50(9).xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\SSAFY\Desktop\S09P31C106\AI\TH\stock_code_learning\stock_num_learning_GRU.ipynb Cell 3 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/stock_code_learning/stock_num_learning_GRU.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/stock_code_learning/stock_num_learning_GRU.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> # 데이터를 DataFrame으로 변환
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/stock_code_learning/stock_num_learning_GRU.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> df = pd.DataFrame(result_pridict)
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/stock_code_learning/stock_num_learning_GRU.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> # DataFrame을 엑셀 파일로 저장
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/S09P31C106/AI/TH/stock_code_learning/stock_num_learning_GRU.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> df.to_excel('GRU_adamW_50(9).xlsx', index=False)
#
# NameError: name 'result_pridict' is not defined
